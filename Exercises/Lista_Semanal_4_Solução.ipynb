# %% [markdown]
# **1)** Suponha que o semestre só possua duas disciplinas: Cálculo II e Linguagens de Programação. Crie uma função `boletim()` que recebe duas tuplas (ou listas) de três elementos representando as notas da A1, A2 e AS nesta ordem. A primeira tupla (ou lista) se refere às notas de Cálculo II e a segunda, de Lingagens de Programação. Retorne um dicionário cujas chaves são os nomes da disciplina e os valores são outro dict de chaves 'A1','A2' e 'AS' e valores sendo as notas correspondentes. Veja exemplo abaixo.
#
# >```python
# >>>> boletim((4,8,7),(9,8,0))
# >{'Cálculo II': {'A1': 4, 'A2': 8, 'AS': 7}, 'Linguagens de Programação': {'A1': 9, 'A2': 8, 'AS': 0}}
# ```

# %%
def boletim(x,y):
    d = {'Cálculo II' :
            {'A1' : x[0],
             'A2' : x[1],
             'AS' : x[2]},
         'Linguagens de Programação' : 
            {'A1' : y[0],
             'A2' : y[1],
             'AS' : y[2]}
        }
    return d

boletim((6,4,9),(9,7,0))
# Out:
# {'Cálculo II': {'A1': 6, 'A2': 4, 'AS': 9},
#  'Linguagens de Programação': {'A1': 9, 'A2': 7, 'AS': 0}}

# %% [markdown]
# **2)** Programe a função `ordena()`, que recebe como único argumento um dicionário **d**, para que ordene esse dicionário com base em seus valores e retorne o dicionário ordenado. Os casos de teste não terão valores iguais. Vide exemplos:
#
# >```python
# >>>> ordena({1: 2, 3: 4, 4: 3, 2: 1, 0: 0})
# >{0: 0, 2: 1, 1: 2, 4: 3, 3: 4}
# >
# >>>> ordena({"peixe":1, "ave":10, "bovino":5, "suino":8})
# >{"peixe":1, "bovino":5, "suino":8, "ave":10}
# ```

# %%
def ordena(d):
      return {k: v for k, v in sorted(d.items(), key=lambda item: item[1])}
    
ordena({'oi':3,'teste':1,'dicionário':2})
# Out:
# {'teste': 1, 'dicionário': 2, 'oi': 3}

# %% [markdown]
# **3)** Programe a função `concatena()` para que ela receba como argumentos uma quantidade indeterminada de dicionários. Daí,concatene-os na ordem dada, gerando um único dicionário que deve ser dado como retorno da função. Os casos de teste não terão chaves em comum. Veja os exemplos:
#
# >```python
# >>>> concatena({1:'a',2:'b'},{3:'c',4:'d'},{5:'e',6:'f'})
# >{1:'a',2:'b',3:'c',4:'d',5:'e',6:'f'}
# >
# >>>> concatena({'a':1,'b':2,'c':3},{'d':4,'e':5,'f':6})
# >{'a':1,'b':2,'c':3,'d':4,'e':5,'f':6}
# ```

# %%
def concatena(*l): 
    d={} 
    for x in l: d.update(x)
    return d

print(concatena({1:1.21,2:3.14},{4:'oi',7:'ola'},{3:'hi',5:'hello'},{8:1969,6:2014,9:1854}))
# Out:
# {1: 1.21, 2: 3.14, 4: 'oi', 7: 'ola', 3: 'hi', 5: 'hello', 8: 1969, 6: 2014, 9: 1854}

# %% [markdown]
# **4)** Crie uma classe chamada `Triangulo`, cujo contrutor receba as medidas de seus três lados (em qualquer ordem). Implemente um método chamado `tipo`, que retorne:
# - 0 se as medidas não formam um triângulo
# - 1 se o triângulo for equilátero
# - 2 se o triângulo for isósceles
# - 3 se o triângulo for escaleno
#
# Veja exemplo:
#
# >```python
# >>>> tri = Triangulo(5,5,5) #Equilátero
# >>>> tri.tipo()
# >1
# ```

# %%
class Triangulo:
    def __init__(self,lado1,lado2,lado3):
        [ self.lado1, self.lado2, self.lado3 ] = sorted( [lado1,lado2,lado3])

    def tipo(self):
        if (self.lado1+self.lado2<=self.lado3): return 0
        elif self.lado1 == self.lado2 and self.lado1 == self.lado3:
            return 1
        elif self.lado1 == self.lado2 or \
             self.lado1 == self.lado3 or \
             self.lado2 == self.lado3:
            return 2
        else:
            return 3

Triangulo(3,4,5).tipo()
# Out:
# 3

# %% [markdown]
# **5)** A classe `Point` representa um objeto ponto no plano cartesiano. Programe-a para que ela tenha os métodos `show()`, `move()` e `dist()`. O primeiro deve retornar uma tupla com as coordenadas do ponto. A segunda deve receber como argumentos os deslocamentos em cada um dos eixos e atualizar a posição do objeto. Já a última, deve receber como argumento outro ponto e retornar a distância euclidiana entre os dois pontos. A correção da `dist()` aceitará uma margem de erro de 0.1. Não mude as linhas já existentes nessa questão e não crie ou remova funções ou classes. Com a classe devidamente implementada, deve ser possível executar a seguinte série de comandos:
#
# >```python
# >>>> p1 = Point(2, 3)
# >>>> p2 = Point(3, 3)
# >>>> p1.show()
# >(2, 3)
# >>>> p2.show()
# >(3, 3)
# >>>> p1.move(10, -10)
# >>>> p1.show()
# >(12, -7)
# >>>> p2.show()
# >(3, 3)
# >>>> p1.dist(p2)
# >13.45362404707371
# ```

# %%
class Point(object):
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def show(self):
        return self.x, self.y

    def move(self, x, y):
        self.x += x
        self.y += y

    def dist(self, pt):
        return ((pt.x-self.x)**2 + (pt.y-self.y)**2)**(0.5)
    
p = Point(3,5)
print(p.show())
p.move(5,6)
print(p.show())
q = Point(0,0)
print(p.dist(q))
# Out:
# (3, 5)
# (8, 11)
# 13.601470508735444

# %% [markdown]
# **6)** Você deve programar as duas classes `funcionario` e `gerente` de forma que gerente seja filha de funcionário. Os atributos de funcionario são nome, CPF, salario e departamento. Alem desses, a classe gerente deve ter também como acréscimo os atributos senha e gerenciados (que representa o número de funcionários que ele gerencia). Garanta que seus construtores estejam condizentes. Além disso, a classe funcionario deve ter o metodo `bonificar()`, que não recebe parâmetros e aumenta em 10% o salário do funcionário. A classe gerente deve ter os métodos `autenticarSenha(senha)`, que retorna um booleano resultante da validação do atributo senha com a entrada, e o método `bonificar()`, que aumenta em 15% seu salário. Não mude as linhas já existentes nessa questão e não crie ou remova funções ou classes.
#
# ```python
# >>> f1=funcionario("João",1234567890,2500,"TI")
# >>> f2=funcionario("Paulo",12345678901,1800,"TI")
# >>> f3=gerente("Marta",23456789012,6000,"TI",101101,2)
# >>> f1.nome
# João
# >>> f2.CPF
# 12345678901
# >>> f3.departamento()
# TI
# >>> f2.bonificar()
# >>> f2.salario
# 1980.00 #Consideraremos uma margem de erro
# >>> f3.bonificar()
# 6900.00
# >>> f3.autenticarSenha(101101)
# True
# >>> f3.autenticarSenha(123456)
# False
# ```

# %%
class funcionario():
    def __init__(self,nome,CPF,salario,departamento):
        self.nome=nome
        self.CPF=CPF
        self.salario=salario
        self.departamento=departamento

    def bonificar(self):
        self.salario = 1.1*self.salario

class gerente(funcionario):
    def __init__(self,nome,CPF,salario,departamento,senha,gerenciados):
        funcionario.__init__(self,nome,CPF,salario,departamento)
        self.senha=senha
        self.gerenciados=gerenciados

    def autenticarSenha(self,senha):
        return self.senha==senha

    def bonificar(self):
        self.salario = 1.15*self.salario
        
f1 = funcionario('Pedro',12345678910,2500.00,'RH')
f2 = funcionario('Henrique',51324687951,3475.89,'Vendas')
g1 = gerente('Patrícia',51201012548,8350.00,'Vendas',1234,5)
print(f1.CPF)
print(f2.nome)
print(g1.departamento)
f2.bonificar()
print(f2.salario)
print(g1.autenticarSenha(5678))
(g1.autenticarSenha(1234))
# Out:
# 12345678910
# Henrique
# Vendas
# 3823.4790000000003
# False
# True

# %% [markdown]
# ## Desafio
#
# **7)** Há um arquivo chamado "alice.txt", na qual se encontra o primeiro capítulo do livro Alice no País das Maravilhas em sua versão em inglês. O texto já foi devidamente limpo, removendo pontuações, caracteres especiais e espaçamentos desnecessários, ou seja, o trabalho sujo já foi feito ;)
#
# Há uma função semipronta que lê o arquivo e carrega o texto para a variável do tipo string chamada "alice"; Sua missão é fazer com que essa função retorne um dicionário cujas chaves são as palavras únicas do texto, e os valores são a quantidade de vezes que cada palavras se repete no capítulo.
#
# Extra: Tente descobrir as top 10 palavras mais usadas. Veja a imagem abaixo para ter uma ideia da resposta (Quanto maior a palavra mais vezes ela se repete).
#
# ![](aux_files/alice.png)
#
# Livro: http://www.gutenberg.org/files/11/11-0.txt
#
# Geração da Imagem: https://pypi.org/project/wordcloud/

# %%
def ler_texto():
    file =  open('aux_files/alice.txt','r')
    alice = file.read()
    file.close()
    
    counts = {}
    for word in alice.split():
        if word not in counts:
            counts[word] = 0
        counts[word]+=1
    return counts
    
ler_texto()
# Out:
# {'down': 23,
#  'the': 92,
#  'rabbit': 9,
#  'hole': 4,
#  'alice': 28,
#  'was': 53,
#  'beginning': 1,
#  'to': 75,
#  'get': 7,
#  'very': 23,
#  'tired': 2,
#  'of': 43,
#  'sitting': 1,
#  'by': 6,
#  'her': 26,
#  'sister': 2,
#  'on': 15,
#  'bank': 1,
#  'and': 65,
#  'having': 3,
#  'nothing': 7,
#  'do': 9,
#  'once': 4,
#  'or': 12,
#  'twice': 1,
#  'she': 80,
#  'had': 20,
#  'peeped': 1,
#  'into': 9,
#  'book': 4,
#  'reading': 1,
#  'but': 22,
#  'it': 67,
#  'no': 11,
#  'pictures': 3,
#  'conversations': 2,
#  'in': 26,
#  'what': 10,
#  'is': 6,
#  'use': 5,
#  'a': 52,
#  'thought': 8,
#  'without': 2,
#  'so': 14,
#  'considering': 2,
#  'own': 2,
#  'mind': 2,
#  'as': 14,
#  'well': 7,
#  'could': 8,
#  'for': 21,
#  'hot': 3,
#  'day': 1,
#  'made': 2,
#  'feel': 2,
#  'sleepy': 2,
#  'stupid': 2,
#  'whether': 2,
#  'pleasure': 1,
#  'making': 1,
#  'daisy': 1,
#  'chain': 1,
#  'would': 7,
#  'be': 13,
#  'worth': 1,
#  'trouble': 1,
#  'getting': 3,
# ...

# %%
counts_sorted = {k: v for k, v in sorted(counts.items(), key=lambda x: -x[1])}
for k,v in counts_sorted.items():
    print(f"{k} -- {v}")
# Out:
# the -- 92
# she -- 80
# to -- 75
# it -- 67
# and -- 65
# was -- 53
# a -- 52
# of -- 43
# i -- 35
# alice -- 28
# that -- 27
# her -- 26
# in -- 26
# down -- 23
# very -- 23
# but -- 22
# for -- 21
# had -- 20
# you -- 19
# not -- 16
# on -- 15
# little -- 15
# so -- 14
# as -- 14
# be -- 13
# out -- 13
# way -- 13
# this -- 13
# herself -- 13
# or -- 12
# up -- 12
# there -- 12
# me -- 12
# no -- 11
# with -- 11
# think -- 11
# at -- 11
# like -- 11
# what -- 10
# when -- 10
# all -- 10
# see -- 10
# if -- 10
# rabbit -- 9
# do -- 9
# into -- 9
# time -- 9
# how -- 9
# one -- 9
# ll -- 9
# which -- 9
# thought -- 8
# could -- 8
# about -- 8
# were -- 8
# said -- 8
# s -- 8
# get -- 7
# nothing -- 7
# well -- 7
# would -- 7
# went -- 7
# found -- 7
# eat -- 7
# door -- 7
# by -- 6
# is -- 6
# much -- 6
# say -- 6
# either -- 6
# wonder -- 6
# going -- 6
# they -- 6
# off -- 6
# through -- 6
# key -- 6
# use -- 5
# suddenly -- 5
# shall -- 5
# then -- 5
# never -- 5
# before -- 5
# ...

# %%
import unittest

class UnitTests(unittest.TestCase):
    
    def test_boletim(self):

        # Failure message: 
        # Falha na implementação da função boletim

        a = {'Cálculo II': {'A1': 6, 'A2': 0, 'AS': 7}, 'Linguagens de Programação': {'A1': 9, 'A2': 3, 'AS': 8}}
        b = {'Cálculo II': {'A1': 9, 'A2': 1, 'AS': 4}, 'Linguagens de Programação': {'A1': 8, 'A2': 10, 'AS': 0}}
        c = {'Cálculo II': {'A1': 5, 'A2': 4, 'AS': 10}, 'Linguagens de Programação': {'A1': 9, 'A2': 7, 'AS': 0}}
        d = {'Cálculo II': {'A1': 3.5, 'A2': 8, 'AS': 7}, 'Linguagens de Programação': {'A1': 7, 'A2': 4, 'AS': 9}}

        self.assertEqual(boletim((6,0,7),(9,3,8)),a)
        self.assertEqual(boletim([9,1,4],[8,10,0]),b)
        self.assertEqual(boletim((5,4,10),(9,7,0)),c)
        self.assertEqual(boletim([3.5,8,7],[7,4,9]),d)
        
        
    def test_ordena(self):

        # Failure message: 
        # Falha na implementação da função ordena

        d1={1:0,9:3,8:5,3:8,5:8,0:2,12:8,17:0,7:-1,-15:13,11:6}
        r1={7:-1,1:0,17:0,0:2,9:3,8:5,11:6,3:8,5:8,12:8,-15:13}
        self.assertEqual(ordena(d1),r1)

        d2={1:0,4:5,2:6,3:9,6:4,5:3,7:2,8:8,0:1,9:7}
        r2={1:0,0:1,7:2,5:3,6:4,4:5,2:6,9:7,8:8,3:9}
        self.assertEqual(ordena(d2),r2)

        d3={'a':18,'b':3,'c':-2,'d':0,'e':5,'f':13,'g':7}
        r3={'c':-2,'d':0,'b':3,'e':5,'g':7,'f':13,'a':18}
        self.assertEqual(ordena(d3),r3)

        
    def test_concatena(self):

        # Failure message: 
        # Falha na implementação da função concatena

        d1={1:'a',2:'b',3:'c',4:'d'}
        d2={5:0,6:7,7:9,8:8,9:5,10:6}
        d3={'a':1,'e':5,'i':9,'o':15,'u':21}
        d4={'palavra':2,'outra':3,'texto':5}

        self.assertEqual(concatena(d1,d2),{1:'a',2:'b',3:'c',4:'d',5:0,6:7,7:9,8:8,9:5,10:6})
        self.assertEqual(concatena(d2,d4,d3),{5:0,6:7,7:9,8:8,9:5,10:6,'palavra':2,'outra':3,'texto':5,'a':1,'e':5,'i':9,'o':15,'u':21})
        self.assertEqual(concatena(d4,d1,d3,d2),{'palavra':2,'outra':3,'texto':5,1:'a',2:'b',3:'c',4:'d','a':1,'e':5,'i':9,
                                                 'o':15,'u':21,5:0,6:7,7:9,8:8,9:5,10:6})

        
    def test_Triangulo(self):

        # Failure message: 
        # Falha de implementação na classe triângulo

        self.assertEqual(Triangulo(5,5,5).tipo(),1)
        self.assertEqual(Triangulo(10,10,10).tipo(),1)
        self.assertEqual(Triangulo(10,10,5).tipo(),2)
        self.assertEqual(Triangulo(7,2,7).tipo(),2)
        self.assertEqual(Triangulo(1,8,8).tipo(),2)
        self.assertEqual(Triangulo(1,8,7).tipo(),0)
        self.assertEqual(Triangulo(5,4,3).tipo(),3)
        
        
 

    def test_Point(self):

        # Failure message: 
        # Falha na implementação da classe Point

        p1=Point(3,6)
        p2=Point(0,-5)

        self.assertEqual(p1.show(),(3,6))
        self.assertEqual(p2.show(),(0,-5))
        self.assertAlmostEqual(p1.dist(p2),11.40175425099138,delta=0.1)

        p1.move(3,-3)
        p2.move(0,8)

        self.assertEqual(p1.show(),(6,3))
        self.assertEqual(p2.show(),(0,3))
        self.assertEqual(p1.dist(p2),6)
        
        
    def test_funcionario_gerente(self):

        # Failure message: 
        # Falha na implementação das classes funcionario e gerente

        f1=funcionario("A",1,10,"X")
        f2=funcionario("B",2,10,"Y")
        f3=gerente("C",3,100,"Z",1234,2)

        self.assertEqual(f1.nome,"A")
        self.assertEqual(f2.CPF,2)
        self.assertEqual(f3.departamento,"Z")

        f2.bonificar()
        self.assertAlmostEqual(f2.salario,11,delta=0.1)

        f3.bonificar()
        self.assertAlmostEqual(f3.salario,115,delta=0.1)

        self.assertTrue(f3.autenticarSenha(1234))
        self.assertFalse(f3.autenticarSenha(4321))

        
    def test_ler_texto(self):

        # Failure message: 
        # Falha na implementação da função ler_texto

        gabarito = {'down': 23, 'the': 92, 'rabbit': 9, 'hole': 4, 'alice': 28, 'was': 53, 'beginning': 1, 'to': 75, 'get': 7,
                    'very': 23, 'tired': 2, 'of': 43, 'sitting': 1, 'by': 6, 'her': 26, 'sister': 2, 'on': 15, 'bank': 1, 'and': 65,
                    'having': 3, 'nothing': 7, 'do': 9, 'once': 4, 'or': 12, 'twice': 1, 'she': 80, 'had': 20, 'peeped': 1,
                    'into': 9, 'book': 4, 'reading': 1, 'but': 22, 'it': 67, 'no': 11, 'pictures': 3, 'conversations': 2, 'in': 26,
                    'what': 10, 'is': 6, 'use': 5, 'a': 52, 'thought': 8, 'without': 2, 'so': 14, 'considering': 2, 'own': 2,
                    'mind': 2, 'as': 14, 'well': 7, 'could': 8, 'for': 21, 'hot': 3, 'day': 1, 'made': 2, 'feel': 2, 'sleepy': 2,
                    'stupid': 2, 'whether': 2, 'pleasure': 1, 'making': 1, 'daisy': 1, 'chain': 1, 'would': 7, 'be': 13, 'worth': 1,
                    'trouble': 1, 'getting': 3, 'up': 12, 'picking': 1, 'daisies': 1, 'when': 10, 'suddenly': 5, 'white': 2,
                    'with': 11, 'pink': 1, 'eyes': 2, 'ran': 2, 'close': 2, 'there': 12, 'remarkable': 1, 'that': 27, 'nor': 1,
                    'did': 3, 'think': 11, 'much': 6, 'out': 13, 'way': 13, 'hear': 2, 'say': 6, 'itself': 1, 'oh': 4, 'dear': 3,
                    'i': 35, 'shall': 5, 'late': 2, 'over': 3, 'afterwards': 1, 'occurred': 1, 'ought': 1, 'have': 2, 'wondered': 1,
                    'at': 11, 'this': 13, 'time': 9, 'all': 10, 'seemed': 3, 'quite': 4, 'natural': 1, 'actually': 1, 'took': 2,
                    'watch': 2, 'its': 1, 'waistcoat': 2, 'pocket': 2, 'looked': 4, 'then': 5, 'hurried': 1, 'started': 1, 'feet': 2,
                    'flashed': 1, 'across': 2, 'never': 5, 'before': 5, 'seen': 3, 'either': 6, 'take': 1, 'burning': 1,
                    'curiosity': 1, 'field': 1, 'after': 5, 'fortunately': 1, 'just': 3, 'see': 10, 'pop': 1, 'large': 3, 'under': 3,
                    'hedge': 1, 'another': 3, 'moment': 4, 'went': 7, 'how': 9, 'world': 1, 'again': 4, 'straight': 1, 'like': 11,
                    'tunnel': 1, 'some': 1, 'dipped': 1, 'not': 16, 'about': 8, 'stopping': 1, 'herself': 13, 'found': 7, 'falling': 2,
                    'deep': 2, 'fell': 4, 'slowly': 1, 'plenty': 1, 'look': 3, 'wonder': 6, 'going': 6, 'happen': 2, 'next': 1,
                    'first': 4, 'tried': 5, 'make': 2, 'coming': 1, 'too': 5, 'dark': 3, 'anything': 2, 'sides': 1, 'noticed': 2,
                    'they': 6, 'were': 8, 'filled': 1, 'cupboards': 2, 'shelves': 2, 'here': 4, 'saw': 2, 'maps': 1, 'hung': 1,
                    'upon': 4, 'pegs': 1, 'jar': 2, 'from': 3, 'one': 9, 'passed': 1, 'labelled': 1, 'orange': 1, 'marmalade': 1,
                    'great': 2, 'disappointment': 1, 'empty': 1, 'drop': 1, 'fear': 1, 'killing': 1, 'somebody': 1, 'underneath': 1,
                    'managed': 1, 'put': 2, 'past': 1, 'such': 3, 'fall': 4, 'tumbling': 1, 'stairs': 1, 'brave': 1, 'll': 9, 'me': 12,
                    'home': 1, 'why': 2, 'wouldn': 1, 't': 5, 'even': 3, 'if': 10, 'off': 6, 'top': 2, 'house': 1, 'which': 9,
                    'likely': 1, 'true': 1, 'come': 3, 'an': 2, 'end': 2, 'many': 2, 'miles': 2, 've': 2, 'fallen': 1, 'said': 8,
                    'aloud': 1, 'must': 2, 'somewhere': 2, 'near': 1, 'centre': 1, 'earth': 2, 'let': 1, 'four': 1, 'thousand': 1,
                    'you': 19, 'learnt': 1, 'several': 2, 'things': 5, 'sort': 3, 'lessons': 1, 'schoolroom': 1, 'though': 2,
                    'good': 3, 'opportunity': 1, 'showing': 1, 'knowledge': 1, 'listen': 1, 'still': 2, 'practice': 1, 'yes': 1,
                    's': 8, 'right': 4, 'distance': 1, 'latitude': 2, 'longitude': 2, 'got': 4, 'idea': 1, 'nice': 3, 'grand': 1,
                    'words': 3, 'presently': 1, 'began': 3, 'through': 6, 'funny': 1, 'seem': 1, 'among': 2, 'people': 4, 'walk': 1,
                    'their': 2, 'heads': 1, 'downward': 1, 'antipathies': 1, 'rather': 3, 'glad': 1, 'listening': 1, 'didn': 2,
                    'sound': 1, 'word': 1, 'ask': 2, 'them': 3, 'name': 1, 'country': 1, 'know': 3, 'please': 1, 'ma': 1, 'am': 1,
                    'new': 1, 'zealand': 1, 'australia': 1, 'curtsey': 1, 'spoke': 1, 'fancy': 2, 'curtseying': 1, 're': 1, 'air': 2,
                    'manage': 1, 'ignorant': 1, 'little': 15, 'girl': 1, 'asking': 1, 'perhaps': 1, 'written': 1, 'else': 1, 'soon': 4,
                    'talking': 1, 'dinah': 5, 'miss': 1, 'night': 1, 'should': 2, 'cat': 1, 'hope': 1, 'remember': 3, 'saucer': 1,
                    'milk': 1, 'tea': 1, 'my': 5, 'wish': 2, 'are': 1, 'mice': 1, 'm': 1, 'afraid': 1, 'might': 4, 'catch': 1, 'bat': 2,
                    'mouse': 1, 'cats': 4, 'eat': 7, 'bats': 4, 'saying': 2, 'dreamy': 1, 'sometimes': 2, 'couldn': 1, 'answer': 1,
                    'question': 1, 'matter': 1, 'felt': 2, 'dozing': 1, 'begun': 2, 'dream': 1, 'walking': 1, 'hand': 3, 'earnestly': 1,
                    'now': 4, 'tell': 1, 'truth': 1, 'ever': 4, 'thump': 2, 'came': 3, 'heap': 1, 'sticks': 1, 'dry': 1, 'leaves': 1,
                    'bit': 2, 'hurt': 1, 'jumped': 1, 'overhead': 1, 'long': 3, 'passage': 3, 'sight': 1, 'hurrying': 1, 'lost': 1,
                    'away': 1, 'wind': 1, 'turned': 2, 'corner': 2, 'ears': 2, 'whiskers': 1, 'behind': 2, 'longer': 1, 'low': 2,
                    'hall': 4, 'lit': 1, 'row': 1, 'lamps': 1, 'hanging': 1, 'roof': 1, 'doors': 2, 'round': 3, 'locked': 1, 'been': 1,
                    'side': 1, 'other': 2, 'trying': 3, 'every': 1, 'door': 7, 'walked': 1, 'sadly': 1, 'middle': 1, 'wondering': 1,
                    'three': 1, 'legged': 1, 'table': 5, 'solid': 1, 'glass': 3, 'except': 1, 'tiny': 1, 'golden': 3, 'key': 6,
                    'belong': 1, 'alas': 2, 'locks': 1, 'small': 3, 'any': 4, 'rate': 2, 'open': 1, 'however': 3, 'second': 1,
                    'curtain': 1, 'fifteen': 1, 'inches': 2, 'high': 2, 'lock': 1, 'delight': 1, 'fitted': 1, 'opened': 2, 'led': 1,
                    'larger': 2, 'than': 1, 'rat': 1, 'knelt': 1, 'along': 1, 'loveliest': 1, 'garden': 4, 'longed': 1, 'wander': 1,
                    'those': 2, 'beds': 1, 'bright': 1, 'flowers': 1, 'cool': 1, 'fountains': 1, 'head': 3, 'doorway': 1, 'go': 2,
                    'poor': 4, 'shoulders': 1, 'shut': 1, 'telescope': 2, 'only': 2, 'knew': 1, 'begin': 1, 'happened': 2, 'lately': 1,
                    'few': 2, 'indeed': 2, 'really': 1, 'impossible': 1, 'waiting': 1, 'back': 2, 'half': 1, 'hoping': 1, 'find': 2,
                    'rules': 2, 'shutting': 2, 'telescopes': 1, 'bottle': 4, 'certainly': 1, 'neck': 1, 'paper': 1, 'label': 1,
                    'drink': 3, 'beautifully': 2, 'printed': 1, 'letters': 1, 'wise': 1, 'hurry': 1, 'marked': 4, 'poison': 3,
                    'read': 1, 'histories': 1, 'children': 1, 'who': 1, 'burnt': 1, 'eaten': 1, 'wild': 1, 'beasts': 1, 'unpleasant': 1,
                    'because': 1, 'simple': 1, 'friends': 1, 'taught': 1, 'red': 1, 'poker': 1, 'will': 1, 'burn': 1, 'hold': 1,
                    'cut': 1, 'your': 1, 'finger': 1, 'deeply': 1, 'knife': 1, 'usually': 1, 'bleeds': 1, 'forgotten': 2, 'almost': 1,
                    'certain': 1, 'disagree': 1, 'sooner': 1, 'later': 1, 'ventured': 1, 'taste': 1, 'finding': 2, 'fact': 1,
                    'mixed': 1, 'flavour': 1, 'cherry': 1, 'tart': 1, 'custard': 1, 'pine': 1, 'apple': 1, 'roast': 1, 'turkey': 1,
                    'toffee': 1, 'buttered': 1, 'toast': 1, 'finished': 2, 'curious': 2, 'feeling': 1, 'ten': 1, 'face': 1,
                    'brightened': 1, 'size': 2, 'lovely': 1, 'waited': 1, 'minutes': 1, 'shrink': 1, 'further': 1, 'nervous': 1,
                    'altogether': 1, 'candle': 3, 'flame': 1, 'blown': 1, 'thing': 2, 'while': 1, 'more': 1, 'decided': 1,
                    'possibly': 1, 'reach': 2, 'plainly': 1, 'best': 1, 'climb': 1, 'legs': 1, 'slippery': 1, 'sat': 1, 'cried': 1,
                    'crying': 1, 'sharply': 1, 'advise': 1, 'leave': 1, 'minute': 1, 'generally': 2, 'gave': 1, 'advice': 1,
                    'seldom': 1, 'followed': 1, 'scolded': 1, 'severely': 1, 'bring': 1, 'tears': 1, 'remembered': 1, 'box': 2,
                    'cheated': 1, 'game': 1, 'croquet': 1, 'playing': 1, 'against': 1, 'child': 1, 'fond': 1, 'pretending': 1,
                    'two': 2, 'pretend': 1, 'hardly': 1, 'enough': 1, 'left': 1, 'respectable': 1, 'person': 1, 'eye': 1, 'lying': 1,
                    'cake': 3, 'currants': 1, 'makes': 2, 'grow': 2, 'can': 2, 'smaller': 1, 'creep': 1, 'don': 1, 'care': 1,
                    'happens': 2, 'ate': 1, 'anxiously': 1, 'holding': 1, 'growing': 1, 'surprised': 1, 'remained': 1, 'same': 1,
                    'sure': 1, 'eats': 1, 'expecting': 1, 'dull': 1, 'life': 1, 'common': 1, 'set': 1, 'work': 1}
        aluno = ler_texto()

        self.assertEqual(aluno,gabarito)
    
        
unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .......
# ----------------------------------------------------------------------
# Ran 7 tests in 0.005s
#
# OK
