# %% [markdown]
# <img src="https://communications.univie.ac.at/fileadmin/_processed_/csm_Uni_Logo_2016_2f47aacf37.jpg"
#      alt="Logo Universität Wien"
#      width="200"/>
#
# # Practical Machine Learning for Natural Language Processing - 2023 SS
#
# ### Assigment 1 - Python for Poets
#
# This assigment is an adaptation for Python of the original exercise ["Unix for Poets"](https://www.cs.upc.edu/~padro/Unixforpoets.pdf)

# %%
import string
import re

# %% [markdown]
# ### Loading the document

# %%
with open("../../Data/txt/nyt_200811.txt", "r") as f:
    text = f.read()

print(text[0:500])
# Out:
# KBR said Friday the global economic downturn so far has
# had
# little effect on its business but warned some projects on its books
# could be in jeopardy if the headwinds persist into next year.
#
# "With the economic outlook remaining uncertain, it is possible
# that
# customers may cancel or delay projects that are under way," said
# William
# Utt, chief executive of the Houston-based engineering and
# construction
# giant and government contractor.
#
# He did not predict how much of the company's $15.3billion in
# fu

# %% [markdown]
# ***

# %% [markdown]
# ### You will solve the following exercises using **Pure Python**
# ### (only packages "string" and "re" are allowed).
#
# 1. Count words in a text
# 2. Sort a list of words in various ways
#    • ascii order
#    • "rhyming" order
# 3. Extract useful info for a dictionary
# 4. Compute ngram statistics
# 5. Make a Concordance

# %% [markdown]
# ***

# %% [markdown]
# #### 1. Count words in a text
#
# a. Output a list of words in the file along with their frequency counts (ignoring case).
# a. Count how many unique words there are (ignoring case).
# c. Check how common are all different sequences of vowels (e.g. the sequences "ieu" or just "e" in "lieutenant")?

# %%
# a)
def word_count():
    
# word_count = {}
    lower_strip_tokens = text.strip(string.punctuation).lower().split()
    unique_tokens = set(lower_strip_tokens)
    counted_words={}
    for unique_token in unique_tokens:
        counted_words.update({unique_token:lower_strip_tokens.count(unique_token)})
    yield(counted_words)
            
list(word_count())
            
            
            #iterator = ({word:lower_strip_tokens.count(word)} for word in set(lower_strip_tokens))
#list(iterator)
#for word in set(lower_strip_tokens):
#    word_count.update({word:lower_strip_tokens.count(word)})
#print(word_count)
# Out:
# [{'"without': 3,
#   '1980s': 10,
#   'passes,': 4,
#   'soldat"': 1,
#   '236': 1,
#   'drinking"': 1,
#   '(twice)': 1,
#   "harrah's,": 2,
#   'looks,': 1,
#   'invest.': 1,
#   'yellowed': 1,
#   'pie.': 1,
#   'listens.': 1,
#   '"abbreviated"': 1,
#   'election-year': 1,
#   'wretched': 1,
#   'kennedy.': 3,
#   'council,': 11,
#   'modifying': 1,
#   'reichert': 1,
#   'prospect.1,': 3,
#   'sepracor,': 2,
#   'mourn': 3,
#   'celebrity-chaser,': 1,
#   '"godless': 1,
#   'gm.': 1,
#   'ontario-architecture': 1,
#   'cap': 8,
#   'eat.': 2,
#   'different:': 1,
#   '((completions))': 1,
#   'destroy': 3,
#   'destabilize': 1,
#   'threats,': 1,
#   'rich': 27,
#   'report,': 19,
#   'advantage).': 1,
#   'concluding': 3,
#   'hawkeye': 1,
#   'halfway.': 1,
#   'smallest.': 1,
#   'baffling': 2,
#   'fantasies': 2,
#   'clout.': 1,
#   'recourse': 1,
#   'immigrants': 16,
#   'classmate,': 1,
#   'medically': 1,
#   'struggled.': 2,
#   'rumblings': 1,
#   '34-yard': 3,
#   'instant-on': 1,
#   '"america"': 1,
#   'booted;': 1,
#   'street-lit': 2,
#   '175': 4,
#   'conquer': 2,
#   'unbridled': 1,
#   'almane,': 2,
#   'coluche,': 1,
#   'checkers': 2,
#   'prey.': 1,
#   '"wamu': 1,
#   'gaudy': 1,
#   'appreciation': 5,
#   'opens': 12,
#   'cadet."': 1,
#   'program."': 1,
#   'cracking': 1,
#   'other,"': 1,
#   'pulliam,': 1,
#   'missing': 26,
#   'desktop': 1,
#   'specially': 1,
#   'shine': 3,
#   '?american': 1,
#   'consumed,': 1,
#   'carnival': 2,
#   'heartbreak"': 1,
#   'trajectory.': 1,
#   'signs': 50,
#   'musical."': 1,
#   'explores': 4,
#   'games.': 47,
#   'soldier"': 1,
#   'humanities': 3,
#   'heartthrob': 1,
#   'darkness': 2,
#   'game-high': 2,
#   'post-conviction': 2,
#   'seen."': 2,
#   'limelight.': 1,
#   'deciders': 1,
#   '40-foot': 1,
#   'planet.': 2,
#   'unrehearsed': 1,
#   'catholic,': 4,
#   'basque': 2,
#   'flares': 38,
#   '(dodgers);': 1,
#   'inside,': 4,
#   'intoxicated': 3,
#   'performs': 2,
#   'glaze': 1,
#   'www.culture.gr.': 2,
#   'laboratory,': 3,
#   'resounding': 4,
#   'heavyweight': 1,
#   'dyer': 1,
#   'withdrawals': 4,
#   'campuses."': 1,
#   'receivers': 13,
#   'varitek,': 2,
#   'pedestal.': 1,
#   'eln-blacks-vote.': 1,
#   "majority's": 1,
#   'banter': 1,
#   'distributes': 2,
#   'exaggerated.': 2,
#   'illusion."': 1,
#   'contention': 4,
#   '"tensions"': 1,
#   'rail': 6,
#   '(18)': 1,
#   'roughing': 2,
#   'whales,': 5,
#   'coolers': 1,
#   '1960s,': 7,
#   'assignments,': 1,
#   'wavelengths': 1,
#   '"clawbacks"': 2,
#   'climate,': 4,
#   'temperaments.': 1,
#   'oil-dependent': 1,
#   'robbed': 1,
#   'staggers,': 1,
#   'transformational.': 1,
#   'lausd,': 1,
#   'ambitious': 10,
#   'rosemary-': 1,
#   'anyway."': 1,
#   'misgivings': 1,
#   'palin?': 1,
#   'lampposts': 1,
#   'sonnenshine;': 1,
#   '$431': 1,
#   'marian': 3,
#   'blitzing': 1,
#   'him."': 16,
#   'cox': 20,
#   'defensively,': 2,
#   'sadness,': 1,
#   'ran,': 1,
#   '"wiping': 1,
#   'amore': 1,
#   'informal,': 1,
#   'c?zanne': 1,
#   "spain's": 8,
#   "days'": 2,
#   'with;': 1,
#   'takashi': 3,
#   'braylon': 2,
#   'caramanica': 1,
#   'jokesters': 1,
#   'harm."': 2,
#   'luthier': 1,
#   'conjoined': 1,
#   'multilateral': 3,
#   'rivera,': 1,
#   'eleanor,': 1,
#   '5-2,': 1,
#   'verifies': 1,
#   'sick."': 1,
#   'humanly': 1,
#   'kriegbaum': 5,
#   'equivalent."': 1,
#   'diloreto': 2,
#   'jabr': 2,
#   'dialogue': 3,
#   'methicillin-resistant': 1,
#   "tracy's": 1,
#   'craig?"': 1,
#   'punchy': 1,
#   'buddies': 1,
#   'place,': 18,
#   'overnight,': 1,
#   'product,"': 1,
#   'chats': 1,
#   'intervention.': 2,
#   'all)': 1,
#   'kcet': 1,
#   'excuses': 3,
#   'rights,': 5,
#   'here.)': 1,
#   'steer': 2,
#   'plus-8': 1,
#   'prayers': 3,
#   'dedicated': 2,
#   'nears,': 1,
#   'numbers.': 10,
#   'fuentes.': 2,
#   'body,': 4,
#   'accepting': 7,
#   'biden,': 14,
#   "ohio's": 2,
#   'mcconnell,': 3,
#   'me?': 4,
#   'predisposed': 1,
#   '(with': 4,
#   'gallons': 2,
#   '$3-a-day': 1,
#   'jokes:': 1,
#   'essential': 12,
#   'digital,': 2,
#   'planted.': 1,
#   'wealthy.': 1,
#   'prudish': 1,
#   '401(k).': 1,
#   'ashamed': 2,
#   'contrary."': 1,
#   'overwrought.': 1,
#   'middle-aged': 3,
#   'anchors': 1,
#   'c.': 20,
#   'lenses': 1,
#   'iverson': 22,
#   'fee).': 1,
#   'mandela': 1,
#   'defeating': 2,
#   'inflation.': 4,
#   'stretches': 8,
#   'swings,': 1,
#   'plentiful': 1,
#   'calls,': 4,
#   'distress': 1,
#   'sasson,': 1,
#   'bangkok,': 1,
#   'fda."': 1,
#   'shaft,"': 1,
#   'colon': 7,
#   'glacier.': 1,
#   'cusp': 2,
#   'resulting': 11,
#   'models.': 7,
#   'church?': 1,
#   'predictable': 2,
#   'biggest': 114,
#   'cooperation': 7,
#   'dressed"': 1,
#   'strummer': 1,
#   'damn': 2,
#   "restaurant's": 1,
#   'singling': 3,
#   'to': 12770,
#   'arrive': 14,
#   'luring': 4,
#   'moss': 4,
#   'campaign--all': 1,
#   'pain,': 3,
#   'williamson': 2,
#   '2-of-6': 1,
#   "tuesday's": 37,
#   'gangsta': 1,
#   'tart': 2,
#   'mornings.': 2,
#   'richard.': 1,
#   'explosives-laden': 2,
#   'powerhouse': 2,
#   'officials:': 2,
#   'www.palmengarten-frankfurt.de).': 1,
#   'moldings.': 1,
#   'response.': 4,
#   'bengals,': 2,
#   'poe-like': 1,
#   'corp.,': 17,
#   'vista.': 1,
#   'wage-earning': 1,
#   "god's": 1,
#   'lay': 16,
#   'unapologetically': 2,
#   'dunmore,': 2,
#   'killings': 2,
#   'workboat': 1,
#   'roethlisberger': 2,
#   'spent,': 3,
#   'contending': 5,
#   'cancer': 17,
#   "trig.'": 1,
#   'colleges': 20,
#   'jazz,"': 1,
#   'jamaican': 1,
#   'collection,': 3,
#   'backdrops,': 1,
#   'yorvit': 1,
#   'successor': 3,
#   'twitter': 4,
#   'fehrenbach': 1,
#   'enthusiasm,': 2,
#   '1998': 5,
#   'aerospace,': 1,
#   'minions': 1,
#   'reporter': 26,
#   'bail': 2,
#   'peppers': 3,
#   'undergarments': 1,
#   'annotating': 1,
#   'rings.': 1,
#   '(20),': 1,
#   'issenberg': 1,
#   'conservative.': 2,
#   '(31),': 1,
#   'followed.': 4,
#   'naturalized': 2,
#   "'90s.": 1,
#   "o'leary": 2,
#   '"tax': 1,
#   'handicapped': 1,
#   'data,"': 1,
#   'yesha': 1,
#   'monticello,': 1,
#   'years': 446,
#   'bottles,': 1,
#   'not;': 3,
#   '"establish"': 1,
#   '"twelve': 2,
#   'boom.': 5,
#   'baby-faced': 1,
#   'proposed': 24,
#   'outdoors': 5,
#   'hofheim': 1,
#   'slick,': 1,
#   'psyche': 2,
#   'coin?': 1,
#   "jordan's": 5,
#   'sufficiently': 1,
#   'yeah.': 2,
#   'stellar': 3,
#   'keme': 2,
#   'being,"': 1,
#   'vietnamese': 8,
#   'scans.': 1,
#   'across': 131,
#   'kazan': 2,
#   'ecosystem.")': 1,
#   'rests,': 1,
#   'procrastinator,"': 1,
#   'mediterranean-ness': 1,
#   'meretz': 2,
#   'pleads:': 1,
#   '3-6': 1,
#   'rejuvenated': 2,
#   'dialects': 1,
#   'warranted': 2,
#   'gladys': 1,
#   'fixes': 1,
#   'playhouse,': 1,
#   'temes': 6,
#   'reduced-volume': 1,
#   '346-9867': 2,
#   'lightning': 14,
#   'passing': 31,
#   'reasons:': 1,
#   '15-4': 1,
#   'lines"': 1,
#   'lauderdale,': 1,
#   'playwright.': 1,
#   'conceive': 1,
#   'gondry': 1,
#   'chairmanship,': 1,
#   '((and': 1,
#   "'cookie'.": 1,
#   '45-second': 1,
#   'pecans,': 1,
#   'tanks': 5,
#   '18-hour': 2,
#   'alleging': 4,
#   'crate': 1,
#   'from?"\'': 1,
#   'stars.': 4,
#   '646': 1,
#   'ardor.': 1,
#   'crisis?': 1,
#   'pathologies': 1,
#   'thurber,': 1,
#   'days;': 1,
#   'broder': 2,
#   'existed.': 2,
#   'kits': 4,
#   'keener,': 1,
#   'nominated': 9,
#   'slaps': 1,
#   'paranoia': 2,
#   'suitable': 4,
#   'tv5monde': 1,
#   '2004.)': 1,
#   '$600.': 1,
#   'city': 210,
#   'deductions.': 2,
#   'measurements': 2,
#   '500),': 1,
#   'tacoma': 1,
#   'immune': 9,
#   '(urging': 1,
#   'loving,': 1,
#   'pace,': 5,
#   'riding': 6,
#   'met."': 1,
#   'affiliates': 1,
#   'rampage.': 2,
#   'split-second': 1,
#   'metabolism.': 1,
#   'pictorial': 1,
#   'rubashkin,': 2,
#   'pastors,': 1,
#   'eroding': 2,
#   'balance."': 2,
#   '$4-a-gallon': 1,
#   'banking': 25,
#   'sitcom."': 1,
#   'unpredictable,': 1,
#   'meet,': 1,
#   'profile': 8,
#   'tournaments.': 1,
#   'demise.': 1,
#   'agritourism,"': 1,
#   'camped': 4,
#   'mat': 2,
#   'devoting': 1,
#   'cia,': 2,
#   'borrows': 1,
#   'loop.': 2,
#   'sick,': 2,
#   'refinance.': 1,
#   'taunts': 3,
#   'hesitation': 2,
#   'harvard': 11,
#   'rewired': 1,
#   "kordan's": 6,
#   'hilton.': 2,
#   '34-7': 1,
#   'clubs': 6,
#   'electrician,': 1,
#   'welcomes': 2,
#   'immelt,': 2,
#   'repeating': 7,
#   'aficionado': 1,
#   'knot?': 1,
#   '"super': 1,
#   'disrupt': 1,
#   'confirm.': 1,
#   'indirectly': 2,
#   'forcione': 1,
#   'wising': 1,
#   'chillicothe,': 2,
#   'lapsed': 1,
#   'straps?': 1,
#   'often,"': 1,
#   'patience.': 1,
#   '452,000': 1,
#   'english': 35,
#   'stuff)': 1,
#   'jewelers': 1,
#   '"warmonger"': 2,
#   'nonviolence.': 1,
#   'czech': 20,
#   'asylum,': 1,
#   'roc,': 1,
#   'mirrors': 4,
#   'ho': 2,
#   'initially,': 1,
#   'football"': 1,
#   '($10.8': 1,
#   'takeoff.': 2,
#   'palos': 2,
#   'offer?': 1,
#   '2:30': 2,
#   'foxborough': 2,
#   'with,"': 1,
#   'morpheus,': 1,
#   'exulted': 1,
#   'picks': 4,
#   'angela': 5,
#   'flawed.': 1,
#   'alice': 2,
#   'bartlett.': 1,
#   'continually': 2,
#   'own?': 1,
#   'fdr."': 1,
#   'circuit.': 3,
#   '"irony': 1,
#   'decade,': 7,
#   'please,"\'': 1,
#   'above.': 1,
#   'six-day': 1,
#   'plainer?': 1,
#   'gerhard': 1,
#   'om': 1,
#   'tested': 25,
#   'scarcely': 3,
#   'wagenaar': 1,
#   'off-season,"': 1,
#   'surreal."': 1,
#   'huge,"': 3,
#   'kuba,': 2,
#   'bureau': 13,
#   'persona': 5,
#   '7:02,': 1,
#   'funeral,': 1,
#   'ore.': 1,
#   'richardson-to-parker': 1,
#   'digs': 1,
#   'hug': 2,
#   'laughs': 2,
#   '10.5': 5,
#   "father's.": 1,
#   'dissed': 1,
#   'tampabay.com': 2,
#   'stanley.': 1,
#   'nightmares': 1,
#   'drop': 47,
#   'portraits': 1,
#   'pregame': 7,
#   'legacy."': 1,
#   '(automakers)': 1,
#   'frowns,': 1,
#   'rosier': 1,
#   'locks,': 1,
#   'slowing.': 2,
#   'coat': 2,
#   'world,': 27,
#   'stumping.': 1,
#   'punishing': 4,
#   'gonorrhea': 1,
#   'evidence,': 2,
#   'curiosity': 2,
#   'hydrophone,': 1,
#   '(democrat),': 1,
#   'wounded.': 11,
#   'mike"': 1,
#   'opponents,': 1,
#   "o'connell,": 1,
#   'climate."': 1,
#   'ample': 6,
#   'modernize': 6,
#   'inherited,': 1,
#   'czechoslovakia': 2,
#   'crisis.': 38,
#   'navarro,': 1,
#   'o.j.': 2,
#   '$12.6': 1,
#   'incubate': 1,
#   '(africa,': 1,
#   'concentrate': 4,
#   'telephone?': 1,
#   "voted'": 1,
#   'organization,': 14,
#   'administrations': 1,
#   'professional,': 1,
#   'ground.)': 1,
#   'oputa;': 2,
#   'patterns.': 2,
#   'terrence': 3,
#   'pine': 2,
#   "victor's": 1,
#   'mcdyess,': 3,
#   'manner,': 1,
#   'test,': 11,
#   '98,': 1,
#   'academically': 1,
#   'four-game': 2,
#   'noticed': 10,
#   'dudes': 2,
#   'smoking,': 2,
#   'football."': 1,
#   'depth.': 2,
#   'filters': 1,
#   'entrance.': 1,
#   'tomorrow.': 1,
#   'funk,': 1,
#   'manufacturers.': 1,
#   'socialists,': 1,
#   '19:22.': 1,
#   'evident': 12,
#   'technologically': 6,
#   'ago"': 1,
#   'practically': 10,
#   'akron,': 4,
#   'earle': 1,
#   'hushed': 2,
#   'hindsight,"': 1,
#   '"science': 1,
#   'speech-delayed.': 1,
#   'demographically': 1,
#   'twenty-one': 1,
#   'features,': 2,
#   'sting?': 1,
#   'foreclosures': 5,
#   'bystander': 2,
#   'rob': 9,
#   'slaves,': 1,
#   'brooks,': 1,
#   'ousted': 1,
#   'input"': 1,
#   'germans.': 1,
#   'allegations"': 2,
#   'tourism.': 2,
#   'bickering': 3,
#   '7,500': 1,
#   'dreyfus': 1,
#   'nontax': 1,
#   'penaltiesvermette,': 1,
#   'excited.': 1,
#   'eisenhower,': 1,
#   'identifying': 1,
#   'fluid': 4,
#   'melo,': 1,
#   'foreshadowing,': 1,
#   'parody.': 3,
#   'containers,"': 1,
#   'stringed': 2,
#   "williams'": 8,
#   'announcement': 7,
#   'overpriced,': 1,
#   'ads?': 2,
#   'greek': 15,
#   'laughable.': 1,
#   'angular': 1,
#   'with': 3475,
#   '1920s': 1,
#   'winn?': 1,
#   'forewarned': 1,
#   'experiment"': 1,
#   'zingers': 2,
#   'measures': 26,
#   'one-day': 2,
#   'humbling,': 1,
#   'financing': 53,
#   'scallops': 5,
#   'them?"': 3,
#   'forbidden-fruit': 1,
#   'laughed.': 1,
#   'soap.': 1,
#   'anti-aircraft': 1,
#   'skills."': 1,
#   'elmont': 1,
#   'furnishings': 2,
#   'last-moment': 1,
#   'apologize': 4,
#   'excuse,"': 1,
#   'carbon': 7,
#   '"everyday': 1,
#   'punter': 1,
#   'does:': 1,
#   '11-inch': 1,
#   '$5million.': 1,
#   'slum': 2,
#   'matthews,': 5,
#   'hydraulic': 2,
#   'avatar': 1,
#   'offended': 1,
#   '"four': 1,
#   'favre': 11,
#   'followers': 1,
#   'item': 11,
#   'mind-set:': 1,
#   'individual.': 1,
#   'liquidation': 1,
#   'cockiness': 1,
#   'netherworld': 2,
#   'plantation-style': 1,
#   'expand': 24,
#   'plympton': 1,
#   'openness': 2,
#   '1905': 2,
#   'wrongdoing.': 1,
#   'sensitive.': 2,
#   'investigations': 8,
#   'front.': 6,
#   'hbo.': 1,
#   'ecstatic': 2,
#   '"professional': 1,
#   'electronic': 18,
#   'tanenbaum,': 1,
#   'sheet.': 2,
#   'exciting.': 3,
#   'hemorrhagic': 5,
#   'mcgahee': 1,
#   'momentous': 2,
#   'dispatched': 6,
#   'patrick': 11,
#   'smiling': 1,
#   'cheekily': 1,
#   'bid': 28,
#   '52,': 3,
#   'participants.': 1,
#   'mccain?': 1,
#   'pushmi-pullyu': 1,
#   'inconvenient.': 1,
#   'intime,"': 1,
#   'applicants.': 1,
#   'storming': 2,
#   'counts.': 5,
#   'ferrari.': 1,
#   'corpse,': 1,
#   'untouched': 3,
#   "'heads,": 1,
#   "dorfsman's": 1,
#   'bumptious,': 1,
#   'value,"': 2,
#   'fingernails': 1,
#   'escaping': 1,
#   'noonday': 1,
#   'lsu.': 1,
#   'republicans': 133,
#   '35,"': 1,
#   'hoover,': 2,
#   'naked,': 1,
#   'noon': 2,
#   'dsungaripterus,': 1,
#   'higher-end': 1,
#   'historical': 23,
#   'delay': 13,
#   'somewhat': 16,
#   'guantanamo,': 5,
#   'clarvit,': 1,
#   'fall."': 1,
#   'shiller': 1,
#   'flutes': 1,
#   'replay,': 2,
#   'cha-cha': 1,
#   'keegan.': 1,
#   '1965': 2,
#   '"confer': 1,
#   'cross-curriculum': 1,
#   'catholics.': 3,
#   'returned': 43,
#   '(scribner,': 1,
#   'ut': 1,
#   'renaissance"': 1,
#   'chronicles': 1,
#   'inspiration,': 3,
#   'shrift,': 1,
#   'eccentric': 5,
#   'denomination': 1,
#   'buyout': 12,
#   '41.': 1,
#   "board's": 8,
#   'whorls': 1,
#   'bankrupt,"': 1,
#   'cannon': 1,
#   'shabby': 1,
#   'mars,"': 1,
#   'eager': 21,
#   'outer': 1,
#   'miracle.': 1,
#   'scribner,': 1,
#   'franklin': 23,
#   'levels"': 1,
#   'downtown': 26,
#   '"masters': 1,
#   'teammate.': 2,
#   'incentives': 9,
#   'terror': 3,
#   'shortstop,': 1,
#   'palate': 2,
#   'century': 23,
#   'union,': 9,
#   'filibuster-proof': 3,
#   'perspective,"': 1,
#   'baker;': 1,
#   'elevator': 2,
#   'pascal,': 1,
#   'airing': 12,
#   'running': 213,
#   'born.': 3,
#   'dean.': 3,
#   't-shirts': 8,
#   'stafford': 10,
#   'compared': 59,
#   'rex.': 1,
#   'curtail': 1,
#   "reformers'": 1,
#   '"el': 2,
#   'turnaround': 3,
#   '2005-06.': 1,
#   'firm': 38,
#   'bag,"': 1,
#   'asmerom': 2,
#   'exposure,': 1,
#   'vegetable': 4,
#   'moss,': 2,
#   'morgue': 1,
#   'health-care': 1,
#   'give': 142,
#   'deteriorated,': 1,
#   'sharply': 7,
#   'recordings': 5,
#   'roosevelt,': 5,
#   'one-timer': 1,
#   'co2': 2,
#   'caviar': 2,
#   'it."': 54,
#   'overall,': 6,
#   'broadband': 5,
#   'professorship': 2,
#   'utt': 6,
#   'fast."': 1,
#   'sheryl': 1,
#   'forms:': 2,
#   'hazing,': 1,
#   'factoids': 1,
#   '12.1': 1,
#   'beat.': 1,
#   'outsourcing': 1,
#   'former': 248,
#   'italian-american': 2,
#   'www.insidesocal.com/tv/': 1,
#   'illinois.': 6,
#   '9/11.': 2,
#   'frightening': 3,
#   'blessing,': 3,
#   '"special': 4,
#   'originals.': 1,
#   'registrations': 3,
#   '(drug-addled': 1,
#   'household.': 2,
#   'extended-length,': 1,
#   'grumpy': 1,
#   'streets."': 1,
#   'secret.': 1,
#   'eighth-graders': 1,
#   'listener': 5,
#   'irascible': 1,
#   'vegas.': 3,
#   'creepy': 3,
#   'wreckage': 1,
#   'music-loving': 2,
#   'fixing': 4,
#   'wal-mart': 2,
#   '"sowing': 1,
#   'cat': 2,
#   'nail-biter;': 1,
#   'ied': 1,
#   'pregnancy,': 2,
#   'monarchs': 1,
#   'zoo': 1,
#   'withered': 1,
#   'again': 84,
#   'conforms': 1,
#   '1833,': 3,
#   'illustrate.': 1,
#   'huskies': 6,
#   'attacker': 1,
#   'neighbor.': 2,
#   'medvedev.': 1,
#   'crown.': 3,
#   '(tripping),': 2,
#   'court,': 12,
#   'lewitt.': 1,
#   'stung': 1,
#   'letter).': 1,
#   'chuang': 1,
#   'rapper': 1,
#   'borrowed': 11,
#   'submitted.': 1,
#   'cars,': 11,
#   'weekend,"\'': 1,
#   'accurate.': 1,
#   'stone,"': 1,
#   'specials': 2,
#   'understand.': 3,
#   'productions.': 6,
#   'deeded': 1,
#   'strengthens': 3,
#   'commission.': 2,
#   "'these": 1,
#   "vincent's": 1,
#   'gretzky,': 1,
#   'jamaican-descended': 1,
#   'runoff': 2,
#   'ignited.': 1,
#   'dotting': 2,
#   'contexts': 1,
#   'bong.': 1,
#   'wana,': 2,
#   'mediocrity:': 1,
#   '&amp;lt;/td&gt;&amp;lt;td&gt;2': 2,
#   'incarceration': 1,
#   'debut': 17,
#   'reid."': 1,
#   "mccain's.": 1,
#   'pozo.': 1,
#   'dargis': 2,
#   'mid-august,': 1,
#   'veterinarians': 1,
#   "newspapers'": 1,
#   'intense.': 5,
#   'shaped': 5,
#   'reggaeton': 1,
#   'undefeated': 10,
#   '163': 1,
#   'absolutely,': 1,
#   'strikes': 16,
#   'view,"': 1,
#   'tables': 2,
#   'story."': 2,
#   'yard.': 5,
#   'forgets': 2,
#   'pro-ams': 2,
#   'pine,': 1,
#   'ambiguous': 3,
#   'method.': 2,
#   'relayed': 2,
#   'outfielder': 3,
#   'refer': 4,
#   "edwards'": 5,
#   '38': 14,
#   'expansiveness': 1,
#   'cia': 4,
#   'house,"': 8,
#   'demonstrating': 2,
#   'granato.': 1,
#   '(standard': 1,
#   'r-kan.,': 1,
#   'enrolled.': 1,
#   'creams': 1,
#   'wrist': 2,
#   'egerton,': 1,
#   'distances,': 1,
#   'reviving': 1,
#   'eric,': 2,
#   'eradicating': 1,
#   'below,"': 1,
#   'inheritance': 1,
#   '67-yard': 1,
#   'ai': 1,
#   'ensconced': 2,
#   'auspiciously."': 1,
#   'scrimmaging': 1,
#   'it,': 124,
#   'prosthesis': 1,
#   'surgery': 13,
#   'real-time': 3,
#   "'where": 1,
#   'fuel-distribution': 1,
#   '26': 18,
#   'seatbelt': 1,
#   'up?': 2,
#   '"madam,': 1,
#   'patronized': 1,
#   'successful,"': 1,
#   'hip-hop,': 1,
#   'voting."': 3,
#   'die-offs': 2,
#   'chandra': 1,
#   'amendment.': 5,
#   'transcendence."': 1,
#   'youth.': 3,
#   'whitman': 1,
#   'bonkers': 1,
#   'campus': 21,
#   'glands': 1,
#   'suede': 3,
#   'doper': 1,
#   'midswing,': 1,
#   'czechs,': 1,
#   'articulate': 2,
#   'handwritten': 3,
#   'resolved.': 3,
#   'gtrowbridgedetnews.com.': 1,
#   'symbolic': 3,
#   '"9': 1,
#   'theaters.': 1,
#   'fairways': 1,
#   'giant"': 1,
#   'stake)': 1,
#   'lying': 3,
#   'tears': 3,
#   'salon,': 1,
#   'lord.': 2,
#   'penetration,': 1,
#   'wander': 1,
#   'somehow,"': 1,
#   'northrop': 1,
#   'actively': 3,
#   'crisis,': 19,
#   'whereabouts': 2,
#   '10,000': 13,
#   'more."': 10,
#   '1890,': 1,
#   'ministers,': 1,
#   'priority': 12,
#   '27-6': 1,
#   'encampment': 4,
#   'lazenbyesque;': 1,
#   'pay,': 5,
#   'yankees,': 5,
#   'bedrooms,': 2,
#   'impact,"': 2,
#   'gleam': 3,
#   ...}]

# %%
# b)
print(len(unique_tokens)))
# print(unique_words)
# Out:
# 33156

# %%
# c)

# %% [markdown]
# #### 2. Sorting and reversing lines of text
#
# a. Sort each line alphabetically (ignoring case).
# b. Sort in numeric ([ascii](https://python-reference.readthedocs.io/en/latest/docs/str/ASCII.html)) order.
# c. Alphabetically reverse sort (ignoring case).
# d. Sort in reverse numeric ([ascii](https://python-reference.readthedocs.io/en/latest/docs/str/ASCII.html)) order.

# %%
# a)
def sorting_lines():
    lines = text.strip(string.punctuation).lower().split('\n')
    for line in lines: 
        yield(sorted(line.split()))
        

list(sorting_lines())
# Out:
# [['downturn',
#   'economic',
#   'far',
#   'friday',
#   'global',
#   'has',
#   'kbr',
#   'said',
#   'so',
#   'the'],
#  ['had'],
#  ['books',
#   'business',
#   'but',
#   'effect',
#   'its',
#   'its',
#   'little',
#   'on',
#   'on',
#   'projects',
#   'some',
#   'warned'],
#  ['be',
#   'could',
#   'headwinds',
#   'if',
#   'in',
#   'into',
#   'jeopardy',
#   'next',
#   'persist',
#   'the',
#   'year.'],
#  [],
#  ['"with',
#   'economic',
#   'is',
#   'it',
#   'outlook',
#   'possible',
#   'remaining',
#   'the',
#   'uncertain,'],
#  ['that'],
#  ['are',
#   'cancel',
#   'customers',
#   'delay',
#   'may',
#   'or',
#   'projects',
#   'said',
#   'that',
#   'under',
#   'way,"'],
#  ['william'],
#  ['and',
#   'chief',
#   'engineering',
#   'executive',
#   'houston-based',
#   'of',
#   'the',
#   'utt,'],
#  ['construction'],
#  ['and', 'contractor.', 'giant', 'government'],
#  [],
#  ['$15.3billion',
#   "company's",
#   'did',
#   'he',
#   'how',
#   'in',
#   'much',
#   'not',
#   'of',
#   'predict',
#   'the'],
#  ['future'],
#  ['affected',
#   'be',
#   'business',
#   'but',
#   'commitments',
#   'could',
#   'downplayed',
#   'potential',
#   'the'],
#  ['of'],
#  ['"limited."', 'any', 'as', 'impact', 'significant'],
#  [],
#  ['a',
#   'call',
#   'came',
#   'conference',
#   'discuss',
#   'during',
#   "kbr's",
#   'remarks',
#   'the',
#   'to'],
#  ['third-quarter'],
#  ['35percent',
#   'a',
#   'financial',
#   'improvement',
#   'over',
#   'results,',
#   'showed',
#   'the',
#   'which'],
#  ['same'],
#  ['2007.', 'in', 'period'],
#  [],
#  ['co.',
#   'from',
#   'halliburton',
#   'kbr,',
#   'last',
#   'off',
#   'posted',
#   'spun',
#   'was',
#   'which',
#   'year,'],
#  ['better'],
#  ['a',
#   'acquisition',
#   'after',
#   'analyst',
#   'and',
#   'beat',
#   'expectations',
#   'new',
#   'numbers'],
#  ['helped'],
#  ['and',
#   'because',
#   'boost',
#   'hurricane',
#   'ike.',
#   'losses',
#   'of',
#   'offset',
#   'sales'],
#  [],
#  ['$63',
#   '$85million,',
#   '51',
#   'cents',
#   'from',
#   'income',
#   'net',
#   'or',
#   'per',
#   'rose',
#   'share,',
#   'to'],
#  ['million,'],
#  ['2007.',
#   '37',
#   'cents,',
#   'from',
#   'in',
#   'income',
#   'july-september',
#   'of',
#   'or',
#   'period',
#   'the'],
#  ['44',
#   'cents',
#   'continuing',
#   'including',
#   'operations',
#   'per',
#   'share,',
#   'totaled'],
#  ['hurricane'],
#  ['4', '5', 'a', 'cents', 'costs', 'ike-related', 'of', 'share.', 'to'],
#  [],
#  ['$2.18',
#   '$3.02',
#   '39',
#   'billion',
#   'billion,',
#   'climbed',
#   'from',
#   'percent',
#   'revenue',
#   'to'],
#  ['on', 'the'],
#  ['and',
#   'back',
#   'big',
#   "company's",
#   'gains',
#   'government',
#   'in',
#   'infrastructure',
#   'of',
#   'the'],
#  ['unit'],
#  ['and', 'division.', 'services'],
#  [],
#  ['77',
#   'boosting',
#   'cents',
#   'investors',
#   'kbr',
#   'liked',
#   'saw,',
#   'shares',
#   'they',
#   'to',
#   'what'],
#  ['$14.84', 'in'],
#  ['exchange', 'new', 'stock', 'trading.', 'york'],
#  [],
#  ['and',
#   'commenting',
#   'days,',
#   'earnings',
#   'in',
#   'in',
#   'oil',
#   'on',
#   'recent',
#   'third-quarter'],
#  ['gas'],
#  ['a',
#   'clear',
#   'entering',
#   'executives',
#   'have',
#   'industry',
#   'is',
#   'made',
#   'more',
#   'that',
#   'the'],
#  ['challenging',
#   'credit,',
#   'era,',
#   'extreme',
#   'given',
#   'in',
#   'the',
#   'the',
#   'volatility'],
#  ['financial'],
#  ['and', 'commodity', 'markets.'],
#  [],
#  ['budgets',
#   'capital',
#   'cut',
#   'exploration',
#   'for',
#   'have',
#   'next',
#   'spending',
#   'they'],
#  ['year,'],
#  ['and',
#   'buyback',
#   'generous',
#   'programs',
#   'reassure',
#   'revisited',
#   'stock',
#   'to',
#   'tried'],
#  ['are',
#   'balance',
#   'endure',
#   'enough',
#   'investors',
#   'sheets',
#   'strong',
#   'that',
#   'the',
#   'their',
#   'to'],
#  ['credit', 'crisis.', 'current'],
#  [],
#  ['fundamentals',
#   'like',
#   'long-term',
#   'of',
#   'others,',
#   'said',
#   'the',
#   'the',
#   'the',
#   'utt,'],
#  ['industry'],
#  ['remain', 'strong.'],
#  [],
#  ['benefit',
#   'could',
#   'even',
#   'fall',
#   'from',
#   'he',
#   'kbr',
#   'of',
#   'oil',
#   'prices',
#   'suggested',
#   'the'],
#  ['a', 'into'],
#  ['costs',
#   'has',
#   'helped',
#   'lower',
#   'more',
#   'of',
#   'range,',
#   'raw',
#   'sustainable',
#   'the',
#   'which'],
#  ['and',
#   'costs.',
#   'could',
#   'customers',
#   'encourage',
#   'materials',
#   'other',
#   'project',
#   'that'],
#  ['to'],
#  ['more', 'orders.', 'place'],
#  [],
#  ['"just',
#   'a',
#   'are',
#   'at',
#   'based',
#   'change',
#   'in',
#   'oil',
#   'on',
#   'only,',
#   'price',
#   'still',
#   'the',
#   'we'],
#  ['point'],
#  ['affirmative',
#   'an',
#   'are',
#   'customers',
#   'decision',
#   'investment',
#   'making',
#   'our',
#   'where'],
#  ['for'],
#  ['$150',
#   'crude',
#   'explaining',
#   'near',
#   'prices',
#   'projects,"',
#   'said,',
#   'that',
#   'this',
#   'utt'],
#  ['summer'],
#  ['cooled.',
#   'customers',
#   'delay',
#   'investments',
#   'likely',
#   'prices',
#   'spurred',
#   'to',
#   'until'],
#  [],
#  ['&amp;amp;',
#   'an',
#   'analyst',
#   'holt',
#   'industry',
#   'jeff',
#   'pickering',
#   'tillery,',
#   'tudor',
#   'with'],
#  ['co.'],
#  ['canceled',
#   'houston,',
#   'if',
#   'in',
#   'kbr',
#   'or',
#   'projects',
#   'said',
#   'securities',
#   'sees'],
#  ['delayed,', 'it'],
#  ['be',
#   'early',
#   'engineering',
#   'final',
#   'in',
#   'investment',
#   'stages',
#   'those',
#   'where',
#   'would'],
#  ['been', 'decisions', "haven't", 'made.'],
#  [],
#  ['"the',
#   'a',
#   'changed',
#   'cost',
#   'has',
#   'much',
#   'number',
#   'of',
#   'so',
#   'structure',
#   'that',
#   'these'],
#  ['projects'],
#  ['and',
#   'back',
#   'customer',
#   'go',
#   'going',
#   'have',
#   'he',
#   'is',
#   'just',
#   're-evaluate,"',
#   'the',
#   'to',
#   'to'],
#  ['said.'],
#  [],
#  ['"big',
#   'because',
#   'but',
#   'doubts',
#   'have',
#   'he',
#   'much',
#   'projects',
#   'risk',
#   "there's"],
#  ['already', 'so'],
#  ['already', 'been', 'capital', 'into', 'much', 'put', "that's", 'them."'],
#  [],
#  ['and',
#   'biggest',
#   'building',
#   'business',
#   'designing',
#   'is',
#   "kbr's",
#   'large-scale',
#   'oil'],
#  ['and', 'gas'],
#  ['and',
#   'including',
#   'liquefied',
#   'offshore',
#   'platforms',
#   'projects,',
#   'refineries,'],
#  ['natural'],
#  ['gas', 'terminals.'],
#  [],
#  ['also',
#   'and',
#   'in',
#   'infrastructure',
#   'it',
#   'major',
#   'projects',
#   'takes',
#   'the',
#   'u.s.'],
#  ['abroad,', 'from'],
#  ['airfields',
#   'building',
#   'embassies',
#   'in',
#   'in',
#   'iraq',
#   'other',
#   'repairing',
#   'to'],
#  ['countries.'],
#  [],
#  ['attention', 'but', 'exclusive', 'for', 'it', 'its', 'more', 'receives'],
#  ['multibillion-dollar'],
#  ['contract',
#   'non-military',
#   'pentagon',
#   'provide',
#   'support',
#   'the',
#   'the',
#   'to',
#   'to',
#   'with'],
#  ['u.s.'],
#  ['army', 'east.', 'in', 'middle', 'the'],
#  [],
#  ['among',
#   'be',
#   'beginning',
#   'however,',
#   'next',
#   'spread',
#   'the',
#   'will',
#   'work',
#   'year,'],
#  ['several'],
#  ['40',
#   'and',
#   'contractors,',
#   'expects',
#   'kbr',
#   'of',
#   'percent',
#   'receive',
#   'roughly',
#   'the',
#   'to'],
#  ['work'],
#  ['contract,', 'new', 'said.', 'the', 'under', 'utt'],
#  [],
#  ['decides',
#   'if',
#   'iraq',
#   'new',
#   'of',
#   'out',
#   'president',
#   'pull',
#   'sooner',
#   'the',
#   'to',
#   'u.s.'],
#  ['than'],
#  ['a',
#   'could',
#   'expected,',
#   'in',
#   'increase',
#   'kbr',
#   'mobilize',
#   'see',
#   'short-term',
#   'to',
#   'work'],
#  ['people'],
#  ['and',
#   'before',
#   'down,',
#   'equipment',
#   'iraq',
#   'operations',
#   'said.',
#   'utt',
#   'wind'],
#  [],
#  ['a',
#   'as',
#   'broader',
#   'diversification',
#   'effort',
#   'leaving',
#   'of',
#   'part',
#   'since'],
#  ['halliburton', 'in'],
#  ['2007,',
#   'april',
#   'been',
#   'bulk',
#   'divisions,',
#   'has',
#   'kbr',
#   'other',
#   'to',
#   'trying',
#   'up'],
#  ['including'],
#  ['business.', 'construction', 'domestic', 'its'],
#  [],
#  ['$550million',
#   'a',
#   'announced',
#   'birmingham,',
#   'buy',
#   'deal',
#   'in',
#   'kbr',
#   'may,',
#   'to'],
#  ['ala.-based'],
#  ['and', 'be&amp;amp;k.', 'construction', 'engineering', 'firm'],
#  [],
#  ['and',
#   'closed',
#   'deal',
#   'helped',
#   'in',
#   'in',
#   'july',
#   'kbr',
#   'quarter',
#   'that',
#   'the',
#   'third'],
#  ['boost'],
#  ['600percent', 'at', 'by', 'its', 'revenues', 'services', 'unit.'],
#  [],
#  ['4',
#   '5',
#   'a',
#   'but',
#   'cents',
#   'hit',
#   'in',
#   'kbr',
#   'of',
#   'per',
#   'quarter',
#   'share',
#   'the',
#   'to',
#   'took'],
#  ['after'],
#  ['and',
#   "company's",
#   'damaged',
#   'hurricane',
#   'ike',
#   'knocked',
#   'out',
#   'the',
#   'windows'],
#  ['downtown'],
#  ['billable',
#   'building,',
#   'hours.',
#   'houston',
#   'in',
#   'kbr',
#   'lost',
#   'office',
#   'resulting',
#   'work'],
#  ['also'],
#  ['for',
#   'gulf',
#   'had',
#   'in',
#   'mexico.',
#   'of',
#   'operations',
#   'out',
#   'repairs',
#   'shell',
#   'the',
#   'to',
#   'to'],
#  [],
#  ['downturn',
#   'economic',
#   'far',
#   'friday',
#   'global',
#   'has',
#   'kbr',
#   'said',
#   'so',
#   'the'],
#  ['had'],
#  ['books',
#   'business',
#   'but',
#   'effect',
#   'its',
#   'its',
#   'little',
#   'on',
#   'on',
#   'projects',
#   'some',
#   'warned'],
#  ['be',
#   'could',
#   'headwinds',
#   'if',
#   'in',
#   'into',
#   'jeopardy',
#   'next',
#   'persist',
#   'the',
#   'year.'],
#  [],
#  ['"with',
#   'economic',
#   'is',
#   'it',
#   'outlook',
#   'possible',
#   'remaining',
#   'the',
#   'uncertain,'],
#  ['that'],
#  ['are',
#   'cancel',
#   'customers',
#   'delay',
#   'may',
#   'or',
#   'projects',
#   'said',
#   'that',
#   'under',
#   'way,"'],
#  ['william'],
#  ['and',
#   'chief',
#   'engineering',
#   'executive',
#   'houston-based',
#   'of',
#   'the',
#   'utt,'],
#  ['construction'],
#  ['and', 'contractor.', 'giant', 'government'],
#  [],
#  ['$15.3billion',
#   "company's",
#   'did',
#   'he',
#   'how',
#   'in',
#   'much',
#   'not',
#   'of',
#   'predict',
#   'the'],
#  ['future'],
#  ['affected',
#   'be',
#   'business',
#   'but',
#   'commitments',
#   'could',
#   'downplayed',
#   'potential',
#   'the'],
#  ['of'],
#  ['"limited."', 'any', 'as', 'impact', 'significant'],
#  [],
#  ['a',
#   'call',
#   'came',
#   'conference',
#   'discuss',
#   'during',
#   "kbr's",
#   'remarks',
#   'the',
#   'to'],
#  ['third-quarter'],
#  ['35percent',
#   'a',
#   'financial',
#   'improvement',
#   'over',
#   'results,',
#   'showed',
#   'the',
#   'which'],
#  ['same'],
#  ['2007.', 'in', 'period'],
#  [],
#  ['co.',
#   'from',
#   'halliburton',
#   'kbr,',
#   'last',
#   'off',
#   'posted',
#   'spun',
#   'was',
#   'which',
#   'year,'],
#  ['better'],
#  ['a',
#   'acquisition',
#   'after',
#   'analyst',
#   'and',
#   'beat',
#   'expectations',
#   'new',
#   'numbers'],
#  ['helped'],
#  ['and',
#   'because',
#   'boost',
#   'hurricane',
#   'ike.',
#   'losses',
#   'of',
#   'offset',
#   'sales'],
#  [],
#  ['$63',
#   '$85million,',
#   '51',
#   'cents',
#   'from',
#   'income',
#   'net',
#   'or',
#   'per',
#   'rose',
#   'share,',
#   'to'],
#  ['million,'],
#  ['2007.',
#   '37',
#   'cents,',
#   'from',
#   'in',
#   'income',
#   'july-september',
#   'of',
#   'or',
#   'period',
#   'the'],
#  ['44',
#   'cents',
#   'continuing',
#   'including',
#   'operations',
#   'per',
#   'share,',
#   'totaled'],
#  ['hurricane'],
#  ['4', '5', 'a', 'cents', 'costs', 'ike-related', 'of', 'share.', 'to'],
#  [],
#  ['$2.18',
#   '$3.02',
#   '39',
#   'billion',
#   'billion,',
#   'climbed',
#   'from',
#   'percent',
#   'revenue',
#   'to'],
#  ['on', 'the'],
#  ['and',
#   'back',
#   'big',
#   "company's",
#   'gains',
#   'government',
#   'in',
#   'infrastructure',
#   'of',
#   'the'],
#  ['unit'],
#  ['and', 'division.', 'services'],
#  [],
#  ['77',
#   'boosting',
#   'cents',
#   'investors',
#   'kbr',
#   'liked',
#   'saw,',
#   'shares',
#   'they',
#   'to',
#   'what'],
#  ['$14.84', 'in'],
#  ['exchange', 'new', 'stock', 'trading.', 'york'],
#  [],
#  ['and',
#   'commenting',
#   'days,',
#   'earnings',
#   'in',
#   'in',
#   'oil',
#   'on',
#   'recent',
#   'third-quarter'],
#  ['gas'],
#  ['a',
#   'clear',
#   'entering',
#   'executives',
#   'have',
#   'industry',
#   'is',
#   'made',
#   'more',
#   'that',
#   'the'],
#  ['challenging',
#   'credit,',
#   'era,',
#   'extreme',
#   'given',
#   'in',
#   'the',
#   'the',
#   'volatility'],
#  ['financial'],
#  ['and', 'commodity', 'markets.'],
#  [],
#  ['budgets',
#   'capital',
#   'cut',
#   'exploration',
#   'for',
#   'have',
#   'next',
#   'spending',
#   'they'],
#  ['year,'],
#  ['and',
#   'buyback',
#   'generous',
#   'programs',
#   'reassure',
#   'revisited',
#   'stock',
#   'to',
#   'tried'],
#  ['are',
#   'balance',
#   'endure',
#   'enough',
#   'investors',
#   'sheets',
#   'strong',
#   'that',
#   'the',
#   'their',
#   'to'],
#  ['credit', 'crisis.', 'current'],
#  [],
#  ['fundamentals',
#   'like',
#   'long-term',
#   'of',
#   'others,',
#   'said',
#   'the',
#   'the',
#   'the',
#   'utt,'],
#  ['industry'],
#  ['remain', 'strong.'],
#  [],
#  ['benefit',
#   'could',
#   'even',
#   'fall',
#   'from',
#   'he',
#   'kbr',
#   'of',
#   'oil',
#   'prices',
#   'suggested',
#   'the'],
#  ['a', 'into'],
#  ['costs',
#   'has',
#   'helped',
#   'lower',
#   'more',
#   'of',
#   'range,',
#   'raw',
#   'sustainable',
#   'the',
#   'which'],
#  ['and',
#   'costs.',
#   'could',
#   'customers',
#   'encourage',
#   'materials',
#   'other',
#   'project',
#   'that'],
#  ['to'],
#  ['more', 'orders.', 'place'],
#  [],
#  ['"just',
#   'a',
#   'are',
#   'at',
#   'based',
#   'change',
#   'in',
#   'oil',
#   'on',
#   'only,',
#   'price',
#   'still',
#   'the',
#   'we'],
#  ['point'],
#  ['affirmative',
#   'an',
#   'are',
#   'customers',
#   'decision',
#   'investment',
#   'making',
#   'our',
#   'where'],
#  ['for'],
#  ['$150',
#   'crude',
#   'explaining',
#   'near',
#   'prices',
#   'projects,"',
#   'said,',
#   'that',
#   'this',
#   'utt'],
#  ['summer'],
#  ['cooled.',
#   'customers',
#   'delay',
#   'investments',
#   'likely',
#   'prices',
#   'spurred',
#   'to',
#   'until'],
#  [],
#  ['&amp;amp;',
#   'an',
#   'analyst',
#   'holt',
#   'industry',
#   'jeff',
#   'pickering',
#   'tillery,',
#   'tudor',
#   'with'],
#  ['co.'],
#  ['canceled',
#   'houston,',
#   'if',
#   'in',
#   'kbr',
#   'or',
#   'projects',
#   'said',
#   'securities',
#   'sees'],
#  ['delayed,', 'it'],
#  ['be',
#   'early',
#   'engineering',
#   'final',
#   'in',
#   'investment',
#   'stages',
#   'those',
#   'where',
#   'would'],
#  ['been', 'decisions', "haven't", 'made.'],
#  [],
#  ['"the',
#   'a',
#   'changed',
#   'cost',
#   'has',
#   'much',
#   'number',
#   'of',
#   'so',
#   'structure',
#   'that',
#   'these'],
#  ['projects'],
#  ['and',
#   'back',
#   'customer',
#   'go',
#   'going',
#   'have',
#   'he',
#   'is',
#   'just',
#   're-evaluate,"',
#   'the',
#   'to',
#   'to'],
#  ['said.'],
#  [],
#  ['"big',
#   'because',
#   'but',
#   'doubts',
#   'have',
#   'he',
#   'much',
#   'projects',
#   'risk',
#   "there's"],
#  ['already', 'so'],
#  ['already', 'been', 'capital', 'into', 'much', 'put', "that's", 'them."'],
#  [],
#  ['and',
#   'biggest',
#   'building',
#   'business',
#   'designing',
#   'is',
#   "kbr's",
#   'large-scale',
#   'oil'],
#  ['and', 'gas'],
#  ['and',
#   'including',
#   'liquefied',
#   'offshore',
#   'platforms',
#   'projects,',
#   'refineries,'],
#  ['natural'],
#  ['gas', 'terminals.'],
#  [],
#  ['also',
#   'and',
#   'in',
#   'infrastructure',
#   'it',
#   'major',
#   'projects',
#   'takes',
#   'the',
#   'u.s.'],
#  ['abroad,', 'from'],
#  ['airfields',
#   'building',
#   'embassies',
#   'in',
#   'in',
#   'iraq',
#   'other',
#   'repairing',
#   'to'],
#  ['countries.'],
#  [],
#  ['attention', 'but', 'exclusive', 'for', 'it', 'its', 'more', 'receives'],
#  ['multibillion-dollar'],
#  ['contract',
#   'non-military',
#   'pentagon',
#   'provide',
#   'support',
#   'the',
#   'the',
#   'to',
#   'to',
#   'with'],
#  ['u.s.'],
#  ['army', 'east.', 'in', 'middle', 'the'],
#  [],
#  ['among',
#   'be',
#   'beginning',
#   'however,',
#   'next',
#   'spread',
#   'the',
#   'will',
#   'work',
#   'year,'],
#  ['several'],
#  ['40',
#   'and',
#   'contractors,',
#   'expects',
#   'kbr',
#   'of',
#   'percent',
#   'receive',
#   'roughly',
#   'the',
#   'to'],
#  ['work'],
#  ['contract,', 'new', 'said.', 'the', 'under', 'utt'],
#  [],
#  ['decides',
#   'if',
#   'iraq',
#   'new',
#   'of',
#   'out',
#   'president',
#   'pull',
#   'sooner',
#   'the',
#   'to',
#   'u.s.'],
#  ['than'],
#  ['a',
#   'could',
#   'expected,',
#   'in',
#   'increase',
#   'kbr',
#   'mobilize',
#   'see',
#   'short-term',
#   'to',
#   'work'],
#  ['people'],
#  ['and',
#   'before',
#   'down,',
#   'equipment',
#   'iraq',
#   'operations',
#   'said.',
#   'utt',
#   'wind'],
#  [],
#  ['a',
#   'as',
#   'broader',
#   'diversification',
#   'effort',
#   'leaving',
#   'of',
#   'part',
#   'since'],
#  ['halliburton', 'in'],
#  ['2007,',
#   'april',
#   'been',
#   'bulk',
#   'divisions,',
#   'has',
#   'kbr',
#   'other',
#   'to',
#   'trying',
#   'up'],
#  ['including'],
#  ['business.', 'construction', 'domestic', 'its'],
#  [],
#  ['$550million',
#   'a',
#   'announced',
#   'birmingham,',
#   'buy',
#   'deal',
#   'in',
#   'kbr',
#   'may,',
#   'to'],
#  ['ala.-based'],
#  ['and', 'be&amp;amp;k.', 'construction', 'engineering', 'firm'],
#  [],
#  ['and',
#   'closed',
#   'deal',
#   'helped',
#   'in',
#   'in',
#   'july',
#   'kbr',
#   'quarter',
#   'that',
#   'the',
#   'third'],
#  ['boost'],
#  ['600percent', 'at', 'by', 'its', 'revenues', 'services', 'unit.'],
#  [],
#  ['4',
#   '5',
#   'a',
#   'but',
#   'cents',
#   'hit',
#   'in',
#   'kbr',
#   'of',
#   'per',
#   'quarter',
#   'share',
#   'the',
#   'to',
#   'took'],
#  ['after'],
#  ['and',
#   "company's",
#   'damaged',
#   'hurricane',
#   'ike',
#   'knocked',
#   'out',
#   'the',
#   'windows'],
#  ['downtown'],
#  ['billable',
#   'building,',
#   'hours.',
#   'houston',
#   'in',
#   'kbr',
#   'lost',
#   'office',
#   'resulting',
#   'work'],
#  ['also'],
#  ['for',
#   'gulf',
#   'had',
#   'in',
#   'mexico.',
#   'of',
#   'operations',
#   'out',
#   'repairs',
#   'shell',
#   'the',
#   'to',
#   'to'],
#  [],
#  ['--',
#   '--',
#   'and',
#   'california',
#   'connecticut',
#   'have',
#   'massachusetts,',
#   'states',
#   'three'],
#  ['and',
#   'california',
#   'legalized',
#   'marriage.',
#   'now,',
#   'same-sex',
#   'states,',
#   'three'],
#  ['among',
#   'ballots',
#   'ban',
#   'gay',
#   'have',
#   'month',
#   'on',
#   'proposals',
#   'their',
#   'them,',
#   'this',
#   'to'],
#  ['marriage.'],
#  [],
#  ['but',
#   'federal',
#   'given',
#   'government',
#   'married',
#   'same-sex',
#   'that',
#   'the',
#   'views'],
#  ['as',
#   'couples',
#   'federal',
#   'for',
#   'ineligible',
#   'many',
#   'perfect',
#   'strangers,',
#   'the'],
#  ['couples,',
#   'for',
#   'gay',
#   'given',
#   'married',
#   'opposite-sex',
#   'question',
#   'rights',
#   'the',
#   'to'],
#  ['couples',
#   'is',
#   'is',
#   'it',
#   'it',
#   'knot?',
#   'the',
#   'this:',
#   'tie',
#   'to',
#   'worth'],
#  [],
#  ['a',
#   'answer',
#   'couples,',
#   'for',
#   'is',
#   'many',
#   'resounding',
#   'the',
#   'the',
#   'word',
#   'yes:'],
#  ['"married"',
#   'civil',
#   'conveys',
#   'instantly',
#   'itself',
#   'something',
#   'that',
#   'unions'],
#  ['and', 'do', 'domestic', 'not.', 'partnerships'],
#  [],
#  ['a',
#   'come',
#   'financial',
#   'from',
#   'hard',
#   "it's",
#   'perspective,',
#   'purely',
#   'to',
#   'to',
#   'yet'],
#  ['any',
#   'conclusions.',
#   'couples',
#   'for',
#   'in',
#   'living',
#   'offer',
#   'states',
#   'sweeping',
#   'that'],
#  ['--',
#   'as',
#   'civil',
#   'many',
#   'marriage',
#   'of',
#   'or',
#   'provide',
#   'rights',
#   'same',
#   'the',
#   'unions',
#   'which'],
#  ['--',
#   'be',
#   'definitely',
#   'for',
#   'if',
#   'it',
#   'makes',
#   'marriage',
#   'married',
#   'sense',
#   'them',
#   'they',
#   'to'],
#  ['according',
#   'and',
#   'children,',
#   'estate',
#   'financial',
#   'have',
#   'planners',
#   'planning',
#   'to'],
#  ['lawyers.',
#   'make',
#   'may',
#   'official',
#   'pay',
#   'relationship',
#   'their',
#   'those',
#   'who'],
#  ['also',
#   'estate',
#   'gain',
#   'in',
#   'less',
#   'significantly',
#   'state',
#   'taxes.',
#   'they',
#   'will'],
#  ['and',
#   'hospital',
#   'important',
#   'including',
#   'privileges,',
#   'rights',
#   'the',
#   'visitation'],
#  ['a',
#   'ability',
#   'decisions',
#   'emergencies.',
#   'for',
#   'in',
#   'make',
#   'medical',
#   'partner',
#   'to'],
#  [],
#  ['confers',
#   'many',
#   'marriage',
#   'moment',
#   'rights',
#   'still,',
#   'that',
#   'the',
#   'the',
#   'vaporize'],
#  ['a',
#   'couples',
#   'does',
#   'into',
#   'not',
#   'recognize',
#   'state',
#   'step',
#   'that',
#   'their',
#   'unions.'],
#  [],
#  ['a',
#   'given',
#   'is',
#   'it',
#   'navigate,',
#   'of',
#   'patchwork',
#   'path',
#   'state',
#   'the',
#   'to',
#   'tricky'],
#  ['and',
#   'benefits',
#   'besides',
#   'grades',
#   'laws',
#   'of',
#   'provide.',
#   'the',
#   'they',
#   'three',
#   'varying'],
#  ['--',
#   '--',
#   'allow',
#   'connecticut',
#   'in',
#   'it',
#   'legal',
#   'made',
#   'marriage',
#   'october',
#   'states',
#   'that'],
#  ['allow',
#   'and',
#   'civil',
#   'hampshire',
#   'jersey,',
#   'new',
#   'new',
#   'unions,',
#   'vermont',
#   'which'],
#  ['approximate',
#   'generally',
#   'marriage.',
#   'oregon',
#   'provides',
#   'similar,',
#   'something'],
#  ['but',
#   'calls',
#   'columbia,',
#   'district',
#   'domestic',
#   'it',
#   'of',
#   'partnership.',
#   'the'],
#  ['and',
#   'certain',
#   'hawaii,',
#   'jurisdictions',
#   'maine,',
#   'other',
#   'provide',
#   'washington'],
#  ['constant',
#   'domestic',
#   'flux,',
#   'laws.',
#   'of',
#   'partnership',
#   'rights',
#   'state',
#   'the',
#   'under'],
#  ['all',
#   'as',
#   'ballot,',
#   'by',
#   'illustrated',
#   'it',
#   'makes',
#   'more',
#   'the',
#   'this',
#   "year's"],
#  ['complicated.'],
#  [],
#  ['"it',
#   'are',
#   'david',
#   'depends',
#   'on',
#   'really',
#   'said',
#   'standing,"',
#   'where',
#   'you'],
#  ['and',
#   'at',
#   'buckel,',
#   'counsel',
#   'director',
#   'lambda',
#   'marriage',
#   'project',
#   'senior'],
#  ['"more',
#   '40',
#   'have',
#   'in',
#   'legal',
#   'new',
#   'passed',
#   'states',
#   'statutes',
#   'than',
#   'to',
#   'york.'],
#  ['allowed',
#   'are',
#   'confirm',
#   'couples',
#   'marry."',
#   'not',
#   'same-sex',
#   'that',
#   'to'],
#  [],
#  ['also',
#   'are',
#   'certain',
#   'could',
#   'it',
#   'marry.',
#   'not',
#   'reasons',
#   'ruin',
#   'there',
#   'to',
#   'your'],
#  ['a',
#   'abroad,',
#   'adopting',
#   'because',
#   'chances',
#   'child',
#   'example,',
#   'for',
#   'from',
#   'many',
#   'of'],
#  ['adopt.',
#   'allow',
#   'countries',
#   'couples',
#   'do',
#   'gay',
#   'not',
#   'openly',
#   'to'],
#  [],
#  ['couples',
#   'even',
#   'knowing',
#   'leap,',
#   'legal',
#   'make',
#   'many',
#   'standing',
#   'the',
#   'their'],
#  ['be',
#   'couples.',
#   'equal',
#   'friedman',
#   'jeff',
#   'not',
#   'of',
#   'opposite-sex',
#   'that',
#   'to',
#   'will'],
#  ['40',
#   'and',
#   'and',
#   'andrew',
#   'both',
#   'centre,',
#   'n.y.,',
#   'of',
#   'residents',
#   'rockville',
#   'zwerin,'],
#  ['as',
#   'as',
#   'california',
#   'decided',
#   'in',
#   'it',
#   'legalized',
#   'marry',
#   'may.',
#   'soon',
#   'they',
#   'to'],
#  ['12.',
#   'calif.,',
#   'estates,',
#   'in',
#   'oct.',
#   'on',
#   'palos',
#   'verdes',
#   'wed',
#   'were'],
#  [],
#  ['can',
#   'car',
#   'for',
#   'insurance',
#   'lower',
#   'means',
#   'new',
#   'qualify',
#   'status',
#   'their',
#   'they'],
#  ['"single',
#   'are',
#   'because',
#   'considered',
#   'longer',
#   'males."',
#   'no',
#   'premiums',
#   'they'],
#  ['and',
#   'give',
#   'hope',
#   'if',
#   'legal',
#   'marriage',
#   'more',
#   'standing',
#   'their',
#   'them',
#   'they',
#   'will'],
#  ['5,',
#   'because',
#   'emergency',
#   'his',
#   'in',
#   'joshua,',
#   'lands',
#   'of',
#   'room',
#   'son,',
#   'the',
#   'their'],
#  ['admitted,',
#   'asthma.',
#   'he',
#   'last',
#   'nurse',
#   'pediatric',
#   'the',
#   'the',
#   'the',
#   'time',
#   'told',
#   'was'],
#  ["child's",
#   'dads',
#   'mother.',
#   'needed',
#   'she',
#   'speak',
#   'that',
#   'the',
#   'to',
#   'two',
#   'with'],
#  [],
#  ['are',
#   'aware',
#   'but,',
#   'friedman',
#   'marriage',
#   'said,',
#   'that',
#   'their',
#   'they',
#   'well'],
#  ['carries',
#   'comes',
#   'federal',
#   'filing',
#   'it',
#   'no',
#   'say,',
#   'tax',
#   'their',
#   'to,',
#   'weight',
#   'when'],
#  ['(though',
#   'a',
#   'can',
#   'file',
#   'joint',
#   'return',
#   'return,',
#   'state',
#   'tax',
#   'they',
#   'which',
#   'will'],
#  ['allow',
#   'and',
#   'earnings).',
#   'keep',
#   'marriage',
#   'more',
#   'of',
#   'the',
#   'their',
#   'them',
#   'to'],
#  ['certificate',
#   'couple',
#   'flimsy',
#   'honors',
#   'is',
#   'leaves',
#   'new',
#   'the',
#   'when',
#   'which',
#   'york,'],
#  ['elsewhere.',
#   'family',
#   'marriages',
#   'on',
#   'performed',
#   'same-sex',
#   'the',
#   'vacations,'],
#  ['a',
#   'along',
#   'bring',
#   'continue',
#   'folder,',
#   'manila',
#   'pair',
#   'slightly',
#   'to',
#   'torn',
#   'will'],
#  ['--',
#   'birth',
#   'care',
#   'certificates,',
#   'documentation',
#   'health',
#   'stuffed',
#   'with'],
#  ['adoption',
#   'all',
#   'and',
#   'attorney',
#   'of',
#   'of',
#   'powers',
#   'proxies,',
#   'records',
#   "son's",
#   'their'],
#  ['--', 'a', 'are', 'family.', 'proves', 'that', 'they'],
#  [],
#  ['"our',
#   'a',
#   'also',
#   'help',
#   'hope',
#   'is',
#   'license',
#   'marriage',
#   'might',
#   'providing',
#   'that'],
#  ['additional',
#   'all',
#   'are',
#   'documentation',
#   'for',
#   'how',
#   'of',
#   'proof',
#   'provide',
#   'we'],
#  ['"i',
#   'friedman',
#   'is',
#   'make',
#   'my',
#   'related,"',
#   'said.',
#   'son',
#   'sure',
#   'taken',
#   'to',
#   'want'],
#  ['care', 'happen', 'if', 'me."', 'of', 'something', 'to', 'to', 'were'],
#  [],
#  ['below',
#   'benefits',
#   'couples',
#   'list',
#   'married',
#   'outlines',
#   'same-sex',
#   'the',
#   'the'],
#  ['(and',
#   'as',
#   'as',
#   'civil',
#   'generally',
#   'receive,',
#   'those',
#   'unions)',
#   'well',
#   'what',
#   'with'],
#  ['about.',
#   'are',
#   'as',
#   'be',
#   'concerned',
#   'issues',
#   'need',
#   'not',
#   'still',
#   'these',
#   'they',
#   'to'],
#  ['because',
#   'complicated',
#   'couples,',
#   'for',
#   'many',
#   'opposite-sex',
#   'receive',
#   'they'],
#  ['and',
#   'live,',
#   'marry,',
#   'more',
#   'of',
#   'regardless',
#   'rights',
#   'they',
#   'they',
#   'when',
#   'where'],
#  ['are', 'broadly', 'recognized.', 'rights', 'those'],
#  [],
#  ['attorney', 'medical', 'of', 'power'],
#  [],
#  ['a',
#   'all',
#   'committed',
#   'consider',
#   'couples',
#   'married',
#   'not,',
#   'or',
#   'same-sex',
#   'should'],
#  ['attorney',
#   'care',
#   'for',
#   'health',
#   'matters,',
#   'medical',
#   'of',
#   'or',
#   'power',
#   'which'],
#  ['a',
#   'appoints',
#   'cannot',
#   'decisions',
#   'for',
#   'make',
#   'medical',
#   'person',
#   'to',
#   'when',
#   'you',
#   'you'],
#  ['a',
#   'also',
#   'among',
#   'as',
#   'care',
#   'do',
#   'health',
#   'is',
#   'it',
#   'known',
#   'other',
#   'proxy,',
#   'so.',
#   'things,'],
#  ['an',
#   'depending',
#   'document',
#   'include',
#   'live.',
#   'on',
#   'should',
#   'the',
#   'where',
#   'you'],
#  ['and',
#   'authorization',
#   'health',
#   'insurance',
#   'portability',
#   'the',
#   'under'],
#  ['access',
#   'accountability',
#   'act',
#   'may',
#   'medical',
#   'provide',
#   'records.',
#   'to',
#   'to',
#   'you'],
#  ['a',
#   'also',
#   'can',
#   'directive',
#   'hospital',
#   'include',
#   'specify',
#   'to',
#   'visitation',
#   'who'],
#  ['hospital.', 'in', 'the', 'visit', 'you'],
#  [],
#  ['a',
#   'another',
#   'document',
#   'important',
#   'is',
#   'living',
#   'specifies',
#   'which',
#   'will,'],
#  ['"it',
#   'an',
#   'be',
#   'done.',
#   'is',
#   'may',
#   'may',
#   'medical',
#   'not',
#   'or',
#   'procedures',
#   'which'],
#  ['anyone,',
#   'but',
#   'couples',
#   'document',
#   'for',
#   'for',
#   'important',
#   'more',
#   'same-sex',
#   'so'],
#  ["'no,",
#   'and',
#   'because',
#   'come',
#   'could',
#   'family',
#   'have',
#   'i',
#   'in',
#   'know',
#   'members',
#   'say,',
#   'we'],
#  ['absolutely',
#   'and',
#   'better',
#   'has',
#   'james',
#   'no',
#   'person',
#   'said',
#   'standing,"\'',
#   'this'],
#  ['a', 'financial', 'new', 'planner.', 'tissot,', 'york'],
#  [],
#  ['attorney', 'durable', 'of', 'power'],
#  [],
#  ['a',
#   'becomes',
#   'durable',
#   'if',
#   'incapacitated,',
#   'of',
#   'one',
#   'partner',
#   'power'],
#  ['and',
#   'attorney',
#   'authority',
#   'financial',
#   'gives',
#   'handle',
#   'other',
#   'partner',
#   'the',
#   'to'],
#  ['affairs,', 'bills.', 'legal', 'like', 'paying'],
#  [],
#  ['and', 'trusts', 'wills'],
#  [],
#  ['a',
#   'being',
#   'does',
#   'in',
#   'married',
#   'not',
#   'recognizes',
#   'state',
#   'that',
#   'union',
#   'your'],
#  ['(this',
#   'all',
#   'assets',
#   'go',
#   'goes',
#   'guarantee',
#   'partner.',
#   'that',
#   'to',
#   'will',
#   'your',
#   'your'],
#  ['a',
#   'as',
#   'assets',
#   'couples',
#   'directs',
#   'for',
#   'heterosexual',
#   'how',
#   'well.)',
#   'will',
#   'your'],
#  ['a',
#   'after',
#   'allows',
#   'and',
#   'be',
#   'die',
#   'distributed',
#   'guardian',
#   'name',
#   'to',
#   'will',
#   'you',
#   'you'],
#  ['a',
#   'children.',
#   'for',
#   'hand,',
#   'is',
#   'living',
#   'on',
#   'other',
#   'revocable',
#   'the',
#   'trust,',
#   'your'],
#  ['a',
#   'and',
#   'as',
#   'avoids',
#   'contest',
#   'difficult',
#   'it',
#   'more',
#   'than',
#   'the',
#   'to',
#   'viewed',
#   'will,'],
#  ['a',
#   'and',
#   'deceased',
#   'expensive',
#   'legal',
#   'lengthy',
#   'process',
#   'settle',
#   'sometimes',
#   'to'],
#  ['a',
#   'basically',
#   'estate.',
#   'living',
#   "person's",
#   'put',
#   'revocable',
#   'trust,',
#   'with',
#   'you'],
#  ['all',
#   'and',
#   'assets',
#   'distributes',
#   'in',
#   'name',
#   'the',
#   'the',
#   'trust,',
#   'trustee',
#   'you',
#   'your'],
#  ['according', 'after', 'die.', 'directions', 'them', 'to', 'you', 'your'],
#  [],
#  ['"people',
#   'assume',
#   'documents',
#   "don't",
#   'have',
#   'just',
#   'legal',
#   'need',
#   'they',
#   'to'],
#  ['a',
#   'a',
#   'an',
#   'and',
#   'are',
#   'civil',
#   'drafted',
#   'if',
#   'in',
#   'is',
#   'marriage,',
#   'or',
#   'that',
#   'they',
#   'union'],
#  ['a',
#   'assumption,"',
#   'debra',
#   'entirely',
#   'financial',
#   'neiman,',
#   'planner',
#   'said',
#   'wrong'],
#  ['arlington,', 'in', 'mass.'],
#  [],
#  ['retirement'],
#  [],
#  ['are',
#   'couples',
#   'eligible',
#   'for',
#   'married',
#   'not',
#   'same-sex',
#   'since',
#   'social'],
#  ['benefits,',
#   'make',
#   'may',
#   'more',
#   'need',
#   'or',
#   'save',
#   'security',
#   'survivor',
#   'they',
#   'to'],
#  ['--',
#   '--',
#   'arrangements',
#   'be',
#   'insurance',
#   'life',
#   'like',
#   'purchasing',
#   'special',
#   'sure',
#   'to'],
#  ['enough',
#   'financial',
#   'has',
#   'if',
#   'one',
#   'partner',
#   'resources',
#   'should',
#   'survivor',
#   'the'],
#  ['a',
#   'die.',
#   'for',
#   'if',
#   'instance,',
#   'is',
#   'one',
#   'parent,',
#   'partner',
#   'stay-at-home',
#   'that'],
#  ['for',
#   'higher',
#   'not',
#   'partner',
#   'qualify',
#   "spouse's",
#   'the',
#   'wage-earning',
#   'will'],
#  ['benefits',
#   'dies',
#   'earner',
#   'first,',
#   'if',
#   'peter',
#   'said',
#   'security',
#   'social',
#   'the',
#   'wage'],
#  ['author',
#   'berkery,',
#   'books',
#   'financial',
#   'for',
#   'of',
#   'on',
#   'planning',
#   'same-sex',
#   'two'],
#  ['couples.'],
#  [],
#  ['ownership', 'property'],
#  [],
#  ['care',
#   'couples,',
#   'extra',
#   'married',
#   'need',
#   'not,',
#   'or',
#   'same-sex',
#   'take',
#   'to',
#   'when'],
#  ['especially',
#   'heterosexual',
#   'homes.',
#   'property,',
#   'their',
#   'their',
#   'titling'],
#  ['and',
#   'can',
#   'couples',
#   'estate',
#   'married',
#   'personal',
#   'property',
#   'real',
#   'to',
#   'transfer'],
#  ['and',
#   'each',
#   'estate',
#   'gift',
#   'no',
#   'no',
#   'other',
#   'second',
#   'taxes',
#   'taxes',
#   'the',
#   'until',
#   'with'],
#  ['and',
#   'couples',
#   'dies.',
#   'equivalent',
#   'married',
#   'same-sex',
#   'spouse',
#   'those',
#   'with'],
#  ['benefit',
#   'have',
#   'in',
#   'living',
#   'only',
#   'recognize',
#   'rights',
#   'states',
#   'that',
#   'them',
#   'this'],
#  ['a',
#   'but',
#   'is',
#   'level.',
#   'on',
#   'passing',
#   'property',
#   'same-sex',
#   'spouse',
#   'state',
#   'the',
#   'to'],
#  ['estate',
#   'federal',
#   'first',
#   "spouse's",
#   'still',
#   'subject',
#   'taxes',
#   'the',
#   'to',
#   'upon'],
#  ['2008,',
#   'apply',
#   'assets',
#   'at',
#   'death.',
#   'estate',
#   'federal',
#   'for',
#   'in',
#   'taxes',
#   'valued'],
#  ['$2',
#   'a',
#   'adding',
#   'million.',
#   'more',
#   'of',
#   'same-sex',
#   'spouse',
#   'than',
#   'the',
#   'title',
#   'to',
#   'your'],
#  ['also',
#   'be',
#   'because',
#   'considered',
#   'have',
#   'home',
#   'implications',
#   'it',
#   'may',
#   'tax',
#   'would'],
#  ['a', 'gift.'],
#  [],
#  ['insurance'],
#  [],
#  ['consider',
#   'couples,',
#   'married',
#   'not,',
#   'of',
#   'or',
#   'same-sex',
#   'should',
#   'types',
#   'what'],
#  ['benefits',
#   'for',
#   'go',
#   'insurance',
#   'make',
#   'need',
#   'only',
#   'that',
#   'they',
#   'to',
#   'to',
#   'up'],
#  ['be',
#   'can',
#   'compensate',
#   'couples.',
#   'insurance',
#   'life',
#   'married',
#   'straight',
#   'to',
#   'used'],
#  ['benefits',
#   'certain',
#   'cover',
#   'estate',
#   'federal',
#   'for',
#   'or',
#   'retirement',
#   'taxes.',
#   'to'],
#  [],
#  ['a',
#   'also',
#   'be',
#   'disability',
#   'insurance',
#   'may',
#   'normally,',
#   'purchase.',
#   'wise'],
#  ['benefits',
#   'for',
#   'if',
#   'married',
#   'people',
#   'qualify',
#   'security',
#   'social',
#   'some',
#   'their'],
#  ['are',
#   'become',
#   'children',
#   'disabled,',
#   'especially',
#   'if',
#   'spouses',
#   'their',
#   'young.'],
#  ['but',
#   'do',
#   'likewise,',
#   'long-term-care',
#   'not',
#   'qualify.',
#   'same-sex',
#   'spouses'],
#  ['50,',
#   'age',
#   'around',
#   'at',
#   'be',
#   'because',
#   'considered,',
#   'insurance',
#   'should',
#   'typically'],
#  ['a',
#   'be',
#   'by',
#   'how',
#   'is',
#   'it',
#   'medicaid,',
#   'same-sex',
#   'spouses',
#   'treated',
#   'unclear',
#   'will'],
#  ['administered',
#   'by',
#   'federal',
#   'neiman',
#   'program',
#   'said.',
#   'state,',
#   'the'],
#  [],
#  ['adoption', 'second-parent'],
#  [],
#  ['does',
#   'here.',
#   'if',
#   'is',
#   'marital',
#   'matter',
#   'not',
#   'one',
#   'only',
#   'spouse',
#   'status',
#   'your'],
#  ['a',
#   'adoption.',
#   'best',
#   'birth',
#   'conduct',
#   'is',
#   'it',
#   'parent,',
#   'second-parent',
#   'the',
#   'to'],
#  ['about',
#   'allow',
#   'and',
#   'both',
#   'child',
#   'decisions',
#   'make',
#   'parents',
#   'that',
#   'the',
#   'to',
#   'will'],
#  ['as',
#   'as',
#   'custody',
#   'dies,',
#   'ensure',
#   'event',
#   'in',
#   'one',
#   'parent',
#   'that',
#   'the',
#   'well',
#   'will'],
#  ['adoption',
#   'also',
#   'couple',
#   'give',
#   'parental',
#   'rights',
#   'should',
#   'split.',
#   'the',
#   'will'],
#  ['access',
#   'and',
#   'child',
#   'disability',
#   'health',
#   'insurance',
#   'security',
#   'social',
#   'the',
#   'to'],
#  ['benefits', 'either', 'from', 'or', 'parent.', 'survivor'],
#  [],
#  ['a',
#   'a',
#   'cannot',
#   'get',
#   'if',
#   'in',
#   'live',
#   'second-parent',
#   'state',
#   'where',
#   'you',
#   'you'],
#  ['a',
#   'adoption,',
#   'co-parenting,',
#   'create',
#   'is',
#   'next-best',
#   'option',
#   'shared',
#   'to',
#   'your'],
#  ['according',
#   'agreement,',
#   'custody',
#   'guardianship',
#   'lambda',
#   'legal.',
#   'or',
#   'to'],
#  [],
#  ['gifts'],
#  [],
#  ['are',
#   'federal',
#   'for',
#   'gift',
#   'items',
#   'same-sex',
#   'spouses',
#   'subject',
#   'taxes',
#   'to'],
#  ['$12,000',
#   'add',
#   'annually.',
#   'but',
#   'married',
#   'more',
#   'or',
#   'partners,',
#   'than',
#   'that',
#   'to',
#   'up'],
#  ['can',
#   'directly',
#   'education',
#   'expenses',
#   'for',
#   'for',
#   'medical',
#   'not,',
#   'one',
#   'or',
#   'pay'],
#  ['a',
#   'another',
#   'boston',
#   'consequences.',
#   'estate-planning',
#   'kraft,',
#   'rick',
#   'without'],
#  ['a',
#   'account,',
#   'couples,',
#   'joint',
#   'lawyer',
#   'recommends',
#   'same-sex',
#   'who',
#   'with',
#   'works'],
#  ['and',
#   'as',
#   'as',
#   'expenses',
#   'for',
#   'household',
#   'is',
#   'it',
#   'long',
#   'not',
#   'regular',
#   'used'],
#  ['a',
#   'big',
#   'deposit',
#   'extravagant',
#   'gifts.',
#   'if',
#   'makes',
#   'one',
#   'partner',
#   'technically,'],
#  ['a',
#   'a',
#   'a',
#   'account',
#   'and',
#   'big',
#   'in',
#   'is',
#   'it',
#   'makes',
#   'other',
#   'shared',
#   'the',
#   'withdrawal,'],
#  ['"it\'s',
#   'a',
#   'and',
#   'area,',
#   'definitive',
#   'gift.',
#   'is',
#   'no',
#   'sticky',
#   'taxable',
#   'there'],
#  ['about',
#   'apply',
#   'day-to-day',
#   'guidance',
#   'how',
#   'in',
#   'out',
#   'the',
#   'there',
#   'this',
#   'to'],
#  ['a', 'he', 'household,"', 'of', 'operation', 'said.'],
#  [],
#  ['and',
#   'best',
#   'given',
#   'is',
#   'it',
#   'of',
#   'rights,',
#   'sit',
#   'tangle',
#   'terminology',
#   'the',
#   'to'],
#  ['a',
#   'an',
#   'and',
#   'down',
#   'estate',
#   'financial',
#   'perhaps',
#   'planner,',
#   'planning',
#   'with'],
#  ['individual',
#   'lawyer,',
#   'situation.',
#   'the',
#   'through',
#   'to',
#   'unless',
#   'work',
#   'your'],
#  ['complexities',
#   'federal',
#   'government',
#   'marriage,',
#   'recognizes',
#   'same-sex',
#   'the'],
#  ['"it\'s',
#   'continue.',
#   'drowning',
#   'in',
#   'like',
#   'out',
#   'seeing',
#   'someone',
#   'the',
#   'water',
#   'will'],
#  ["'i",
#   'a',
#   'and',
#   'but',
#   'give',
#   'i',
#   'let',
#   'lifesaver,',
#   'on',
#   'saying,',
#   'them',
#   'them',
#   'will',
#   "won't"],
#  ['a',
#   'boat,"\'',
#   'halloran,',
#   'in',
#   'louise',
#   'p.',
#   'president',
#   'said',
#   'the',
#   'vice',
#   'wealth'],
#  ['at',
#   'barney',
#   'connecticut,',
#   'has',
#   'in',
#   'management',
#   'same-sex',
#   'several',
#   'smith',
#   'who'],
#  ['as', 'clients.', 'couples'],
#  [],
#  ['a', 'american', 'david', 'pratt,', 'student', 'to', 'transfer'],
#  ['a',
#   'after',
#   'almost',
#   'anything',
#   'for',
#   'here,',
#   'ready',
#   'settle',
#   'to',
#   'university',
#   'was'],
#  ['a',
#   'he',
#   'house',
#   'housing',
#   'in',
#   'month-long',
#   'row',
#   'search.',
#   'so,',
#   'the',
#   'visited',
#   'when'],
#  ['georgetown',
#   'he',
#   'neighborhood,',
#   'overlooked',
#   'paint,',
#   'peeling',
#   'the',
#   'the'],
#  ['and',
#   'floorboards,',
#   'shattered',
#   'splintered',
#   'the',
#   'the',
#   'washing',
#   'windows'],
#  ['drained', 'floor.', 'machine', 'onto', 'that', 'the'],
#  [],
#  ['"i',
#   '"i',
#   'all',
#   "didn't",
#   'just',
#   'notice',
#   'pratt',
#   'said.',
#   'things,"',
#   'those',
#   'was'],
#  ['found', 'happy', 'have', 'place."', 'the', 'to'],
#  [],
#  ['and',
#   'august,',
#   'his',
#   'housemates',
#   'in',
#   'in,',
#   'moved',
#   'pratt',
#   'previous',
#   'the',
#   'when'],
#  ['140-year-old',
#   'and',
#   'gone,',
#   "house's",
#   'problems',
#   'tenants',
#   'the',
#   'were',
#   'were'],
#  ['22,',
#   'began',
#   'disenchanted,',
#   'for',
#   'glaring.',
#   'help.',
#   'looking',
#   'pratt,'],
#  [],
#  ['a',
#   'a',
#   'found',
#   'internet',
#   'quick',
#   'search',
#   'thisshouldbeillegal.com,',
#   'web'],
#  ['a',
#   'as',
#   'august',
#   'by',
#   'city',
#   'housing',
#   'in',
#   'of',
#   'officials',
#   'part',
#   'set',
#   'site',
#   'up'],
#  ['and',
#   'and',
#   'campaign',
#   'for',
#   'legal',
#   'looking',
#   'others',
#   'rent',
#   'safe',
#   'students',
#   'to'],
#  ['housing.'],
#  [],
#  ['accounts',
#   'city',
#   'facebook,',
#   'free',
#   'including',
#   'on',
#   'set',
#   'sites,',
#   'the',
#   'up',
#   'web'],
#  ['an',
#   'and',
#   'codes,',
#   'housing',
#   'inspection',
#   'links',
#   'to',
#   'twitter',
#   'with',
#   'wordpress,'],
#  ['a',
#   'and',
#   'by',
#   'checklist',
#   'city,',
#   'database',
#   "landlords'",
#   'of',
#   'searchable',
#   'the',
#   'used'],
#  ['also',
#   'anonymously',
#   'business',
#   'can',
#   'licenses.',
#   'renters',
#   'sites',
#   'the',
#   'to',
#   'use'],
#  ['inspections.', 'or', 'report', 'request', 'to', 'violations'],
#  [],
#  ['"too',
#   'are',
#   'landlords',
#   'of',
#   'off-campus',
#   'often,',
#   'students',
#   'target',
#   'the'],
#  ['a',
#   'argo,',
#   'at',
#   'buck',
#   'expense,"',
#   'linda',
#   'make',
#   'quick',
#   'the',
#   'to',
#   'trying',
#   'your'],
#  ['a',
#   'director',
#   'in',
#   'introduction',
#   'of',
#   'program,',
#   'said',
#   'the',
#   'the',
#   'to',
#   'videotaped'],
#  ['"so',
#   'hands."',
#   'in',
#   'power',
#   'put',
#   'site.',
#   'the',
#   'to',
#   'want',
#   'we',
#   'web',
#   'your'],
#  [],
#  ['9,000',
#   'a',
#   'and',
#   'have',
#   'have',
#   'more',
#   'of',
#   'than',
#   'them',
#   'third',
#   'users',
#   'visited,'],
#  ['city',
#   'database,',
#   'michael',
#   'official',
#   'rupert,',
#   'said',
#   'the',
#   'the',
#   'used',
#   'who',
#   'works'],
#  ['campaign.', 'housing', 'student', 'the', 'with'],
#  [],
#  ['address',
#   'and',
#   'cell',
#   'e-mail',
#   'his',
#   'lists',
#   'number',
#   'on',
#   'phone',
#   'rupert,',
#   'who'],
#  ['200',
#   'had',
#   'he',
#   'inspection',
#   'more',
#   'requests',
#   'said',
#   'site,',
#   'taken',
#   'than',
#   'the',
#   'web'],
#  ['50',
#   'at',
#   'from',
#   'investigations.',
#   'least',
#   'led',
#   'of',
#   'students,',
#   'to',
#   'which'],
#  [],
#  ['are',
#   'as',
#   'many',
#   'of',
#   'on',
#   'relying',
#   'renters.',
#   'rights',
#   'students',
#   'their',
#   'unaware'],
#  ['descriptions',
#   'first',
#   'from',
#   'housing',
#   'impressions',
#   'listings,',
#   'of',
#   'online',
#   'or'],
#  ['be', 'can', 'easy', 'for', 'landlords.', 'prey', 'they', 'unscrupulous'],
#  [],
#  ['a',
#   'argo',
#   'city',
#   'concerns',
#   'ease',
#   'new',
#   'said',
#   "students'",
#   'the',
#   'to',
#   'tool',
#   'wanted'],
#  ['about',
#   'and',
#   'even',
#   'eviction',
#   'for',
#   'illegal',
#   'rentals',
#   'reporting',
#   'retaliation'],
#  ['could',
#   'deal',
#   'help',
#   'officials',
#   'or',
#   'program',
#   'properties.',
#   'said',
#   'the',
#   'unsafe'],
#  ['2004',
#   'daniel',
#   'death',
#   'led',
#   'like',
#   'of',
#   'problems',
#   'that',
#   'the',
#   'those',
#   'to',
#   'with'],
#  ['21-year-old', 'a', 'georgetown', 'rigby,', 'senior.', 'university'],
#  [],
#  ['burning',
#   'died',
#   'his',
#   'inhalation,',
#   'inside',
#   'of',
#   'rigby',
#   'smoke',
#   'trapped'],
#  ['apartment',
#   'basement',
#   'blocks',
#   'campus.',
#   'from',
#   'investigators',
#   'metal',
#   'said'],
#  ['a',
#   'a',
#   'and',
#   'bars',
#   'blocking',
#   'exit',
#   'furnace',
#   'over',
#   'rear',
#   'welded',
#   'windows'],
#  ['escaping',
#   'fire,',
#   'from',
#   'him',
#   'ignited',
#   'prevented',
#   'said',
#   'the',
#   'they',
#   'was',
#   'which'],
#  ['a', 'by', 'candle', 'cigarette.', 'or'],
#  [],
#  ['an',
#   'campus',
#   'fire',
#   'firewatch,',
#   'online',
#   'publication',
#   'student',
#   'that',
#   'tracks'],
#  ['108',
#   '129',
#   'fatalities',
#   'news',
#   'of',
#   'reports,',
#   'said',
#   'that',
#   'through'],
#  ['2000',
#   'campus-related',
#   'deaths',
#   'fire',
#   'in',
#   'occurred',
#   'off-campus',
#   'since'],
#  ['housing.'],
#  [],
#  ['after',
#   'death,',
#   'fire',
#   'officials',
#   "rigby's",
#   'said',
#   'students',
#   'them',
#   'turned'],
#  ['and',
#   'as',
#   'away',
#   'door-to-door',
#   'houses',
#   'inspecting',
#   'installing',
#   'they',
#   'went'],
#  ['detectors.', 'smoke'],
#  [],
#  ['"the',
#   'enough',
#   'methods',
#   'not',
#   'of',
#   'outreach',
#   'reaching',
#   'traditional',
#   'were'],
#  ['about',
#   'because',
#   'contacting',
#   'hesitation',
#   'much',
#   'students',
#   'there',
#   'too',
#   'was'],
#  ['"there',
#   'argo',
#   'government,"',
#   'many',
#   'said.',
#   'too',
#   'unknowns."',
#   'were'],
#  [],
#  ['across',
#   'and',
#   'colleges',
#   'country,',
#   'have',
#   'the',
#   'tried',
#   'universities',
#   'with'],
#  ['degrees', 'landlord-tenant', 'mediate', 'of', 'success', 'to', 'varying'],
#  ['inform',
#   'listings,',
#   'many',
#   'of',
#   'provide',
#   'relationships.',
#   'rental',
#   'students'],
#  ['and',
#   'as',
#   'proper',
#   'refer',
#   'renters',
#   'rights',
#   'students',
#   'the',
#   'their',
#   'to'],
#  ['authorities',
#   'colleges',
#   'disputes.',
#   'few',
#   'housing',
#   'legal',
#   'provide',
#   'settle',
#   'to'],
#  ['for',
#   'have',
#   'off-campus',
#   'problems',
#   'representation',
#   'students',
#   'who',
#   'with'],
#  ['advice.', 'although', 'give', 'housing,', 'legal', 'several'],
#  [],
#  ['"a',
#   'a',
#   'but',
#   'don\'t,"',
#   'listen,',
#   'lot',
#   'lot',
#   'of',
#   'of',
#   'people',
#   'people',
#   'said'],
#  ['coordinator',
#   'esther',
#   'illinois',
#   'of',
#   'of',
#   'pratt,',
#   'student',
#   'the',
#   'university'],
#  ['$20,000',
#   'a',
#   'advertise',
#   'more',
#   'spends',
#   'tenant',
#   'than',
#   'to',
#   'union,',
#   'which',
#   'year'],
#  ['campus.', 'its', 'on', 'services'],
#  [],
#  ['death,',
#   'georgetown',
#   'have',
#   'officials',
#   "rigby's",
#   'since',
#   'university'],
#  ['an',
#   'and',
#   'annual',
#   'authorities',
#   'day',
#   'featuring',
#   'housing',
#   'organized',
#   'safety'],
#  ['a',
#   'battaile,',
#   'department.',
#   'fire',
#   'julie',
#   'said',
#   'spokeswoman,',
#   'the',
#   'university'],
#  ['approach.', "city's", 'new', 'the', 'the', 'university', 'welcomed'],
#  [],
#  ['"the',
#   'biggest',
#   "didn't",
#   'is',
#   'know',
#   'students',
#   'such',
#   'that',
#   'there',
#   'thing',
#   'was'],
#  ['a',
#   'a',
#   'as',
#   'battaile',
#   'could',
#   'get,"',
#   'housing',
#   'inspection',
#   'that',
#   'they',
#   'thing'],
#  ['"they',
#   'information."',
#   'kind',
#   'know',
#   'of',
#   'said.',
#   'that',
#   'to',
#   'want'],
#  [],
#  ['american',
#   'and',
#   'his',
#   'pratt,',
#   'roommates',
#   'senior,',
#   'the',
#   'university',
#   'when'],
#  ['a',
#   'complaints',
#   'from',
#   'got',
#   'manager,',
#   'no',
#   'property',
#   'response',
#   'the',
#   'their',
#   'to'],
#  ['association,',
#   'called',
#   'company',
#   'housing',
#   'pratt',
#   'private',
#   'student',
#   'the'],
#  ['called', 'rupert.'],
#  [],
#  ['a',
#   'an',
#   'and',
#   'checked',
#   'days,',
#   'house,',
#   'inspector',
#   'the',
#   'two',
#   'week',
#   'within'],
#  ['17',
#   'also',
#   'cited',
#   'city',
#   'for',
#   'landlord',
#   'later,',
#   'the',
#   'the',
#   'violations.',
#   'was'],
#  ['brown,',
#   'd.',
#   'house,',
#   'investigations',
#   'lewis',
#   'of',
#   'of',
#   'opened',
#   'owner',
#   'the',
#   'the'],
#  ['a',
#   'and',
#   'did',
#   'have',
#   'license',
#   'not',
#   'property',
#   'property,',
#   'rent',
#   'the',
#   'the',
#   'to',
#   'who'],
#  ['company.', 'management'],
#  [],
#  ['and',
#   'association',
#   'brown,',
#   'company,',
#   'housing',
#   'its',
#   'parent',
#   'student',
#   'the'],
#  ['calls',
#   'did',
#   'for',
#   'housing,',
#   'metropolitan',
#   'not',
#   'repeated',
#   'respond',
#   'to'],
#  ['comment.'],
#  [],
#  ['a',
#   'after',
#   'city,',
#   'contacted',
#   'he',
#   'month',
#   'pratt',
#   'said',
#   'that',
#   'the',
#   'the'],
#  ['completed',
#   'had',
#   'including',
#   'manager',
#   'property',
#   'repairs,',
#   'several',
#   'the'],
#  ['and',
#   'and',
#   'machine,',
#   'on',
#   'others.',
#   'was',
#   'washing',
#   'windows',
#   'working'],
#  [],
#  ['"i\'m', 'forward', 'he', 'looking', 'said.', 'settling', 'this,"', 'to'],
#  [],
#  ['are',
#   'editors',
#   'garry',
#   'hands',
#   'newspaper',
#   'over',
#   'some',
#   'their',
#   'wringing'],
#  ['decision',
#   'doonesbury',
#   'for',
#   'next',
#   'pen',
#   'several',
#   'strips',
#   'to',
#   "trudeau's",
#   'week'],
#  ['as',
#   'barack',
#   'depicting',
#   'election.',
#   'obama',
#   'of',
#   'the',
#   'the',
#   'winner'],
#  [],
#  ['an',
#   'banking',
#   'but',
#   'cartoonist,',
#   'for',
#   'on',
#   'politically',
#   'pugnacious',
#   'the'],
#  ['a', 'advance', 'downside.', 'had', 'in', 'obama', 'week', 'win', 'zero'],
#  [],
#  ['"i',
#   'about',
#   'but',
#   'considered',
#   'election,',
#   'never',
#   'not',
#   'the',
#   'to',
#   'writing'],
#  ['an',
#   'avoid',
#   'had',
#   'i',
#   'it',
#   'lameness,',
#   'on',
#   'outcome,"',
#   'predicate',
#   'to',
#   'trudeau'],
#  ['an', 'e-mail', 'in', 'petersburg', 'st.', 'the', 'times.', 'to', 'wrote'],
#  [],
#  ['"if',
#   'a',
#   'and',
#   'commenting',
#   'flow',
#   'genuine',
#   "i'm",
#   'in',
#   'obama',
#   'on',
#   'the',
#   'wins,'],
#  ['a',
#   'a',
#   'be',
#   'global',
#   "i'm",
#   'if',
#   'phenomenon.',
#   'such',
#   'that',
#   "there'll",
#   'uproar',
#   'wrong,'],
#  ['a',
#   'be',
#   'call',
#   'comic',
#   'going',
#   'goofy',
#   'in',
#   "isn't",
#   'much',
#   'noticed."',
#   'strip',
#   'to'],
#  [],
#  ['already,',
#   'be',
#   'but',
#   'chicago',
#   'may',
#   'modest.',
#   'overly',
#   'the',
#   'tribune',
#   'trudeau'],
#  ['5',
#   'comics',
#   'decided',
#   'has',
#   'its',
#   'nov.',
#   'off',
#   'pages,',
#   'regular',
#   'strip',
#   'take',
#   'the',
#   'to'],
#  ['.',
#   'are',
#   'be',
#   'before',
#   'election',
#   'known',
#   'printed',
#   'results',
#   'the',
#   'which',
#   'will'],
#  [],
#  ['be',
#   'if',
#   'john',
#   'mccain',
#   'newspapers',
#   'sen.',
#   'some',
#   'that',
#   "they'll",
#   'wins,',
#   'worry'],
#  ['"dewey',
#   'an',
#   'at',
#   'four',
#   'least',
#   'like',
#   'ongoing',
#   'read',
#   'strips',
#   'stuck',
#   'that',
#   'with'],
#  ['a',
#   'and',
#   'defeats',
#   "didn't",
#   'happen',
#   'headline',
#   'that',
#   'touting',
#   'truman"',
#   'victory'],
#  ['off', 'readers.', 'some', 'ticking'],
#  [],
#  ['"if',
#   "(doonesbury's)",
#   'elected',
#   'in',
#   'is',
#   'obama',
#   'president',
#   'said',
#   'world,"'],
#  ['bannon,',
#   'chicago',
#   'daily',
#   'editor',
#   'features',
#   'of',
#   'section,',
#   'the',
#   'tim',
#   "tribune's"],
#  ['"will', 'for', 'four', 'he', 'next', 'president', 'stay', 'the', 'years?"'],
#  [],
#  ['"great',
#   'a',
#   'according',
#   'be',
#   'it',
#   'possibly,',
#   'said',
#   'to',
#   'trudeau,',
#   'who',
#   'would'],
#  ['doonesbury',
#   'even',
#   'he',
#   'idea"',
#   'if',
#   'in',
#   'keep',
#   'loses.',
#   'obama',
#   'president',
#   'to'],
#  [],
#  ['at',
#   'editor',
#   'features',
#   'mike',
#   'petersburg',
#   'said',
#   'st.',
#   'the',
#   'times,',
#   'wilson'],
#  ['as',
#   'he',
#   'newspaper',
#   'run',
#   'strips',
#   'the',
#   'them.',
#   "trudeau's",
#   'will',
#   'wrote'],
#  [],
#  ['"if',
#   'and',
#   "he's",
#   'him',
#   'him,',
#   'like',
#   'like',
#   'people',
#   'right,',
#   'still',
#   'the',
#   'the',
#   'who'],
#  ['an',
#   'e-mail.',
#   'hate',
#   'hate',
#   'him',
#   'him,"',
#   'in',
#   'people',
#   'still',
#   'who',
#   'wilson',
#   'wrote'],
#  ['"if',
#   "'dewey",
#   'a',
#   'defeats',
#   'everybody',
#   'gets',
#   "he's",
#   'keepsake,',
#   "truman'",
#   'wrong,'],
#  ['a',
#   'and',
#   'are',
#   'ever.',
#   'happier',
#   'hate',
#   'him',
#   "it's",
#   'no-lose',
#   'people',
#   'than',
#   'the',
#   'who'],
#  ['situation."'],
#  [],
#  ['are',
#   'from',
#   'here',
#   'questions',
#   'responses',
#   'the',
#   'times:',
#   'to',
#   "trudeau's"],
#  [],
#  ['be',
#   'inspired',
#   'knowing',
#   'might',
#   'strip,',
#   'this',
#   'to',
#   'what',
#   'write',
#   'you',
#   'you'],
#  ['wrong?'],
#  [],
#  ['fivethirtyeight.com,',
#   'is',
#   'most',
#   'of',
#   'probably',
#   'respected',
#   'the',
#   'the',
#   'which'],
#  ['3.7',
#   'a',
#   'analysts,',
#   'at',
#   'has',
#   'likelihood',
#   'mccain',
#   'of',
#   'poll',
#   'the',
#   'victory'],
#  ['assessment',
#   'could',
#   'i',
#   'live',
#   'percent.',
#   'risk',
#   'that',
#   'was',
#   'with.'],
#  [],
#  ['are',
#   'deciding',
#   'do',
#   'editors',
#   'not',
#   'of',
#   'run',
#   'the',
#   'think',
#   'to',
#   'what',
#   'who',
#   'you'],
#  ['strip?'],
#  [],
#  ['comics.',
#   'i',
#   'it',
#   'means',
#   'more',
#   'of',
#   'own',
#   'reading',
#   'their',
#   'them.',
#   "they're",
#   'think'],
#  [],
#  ['about',
#   'american',
# ...
#   'stopped',
#   'the',
#   'the',
#   'to',
#   'world'],
#  ['court.', 'supreme', 'u.s.'],
#  [],
#  ['537',
#   'bush',
#   'by',
#   'end,',
#   'florida',
#   'gore',
#   'in',
#   'lost',
#   'the',
#   'the',
#   'to',
#   'vote',
#   'votes.'],
#  [],
#  ['"i\'m',
#   'be',
#   'better',
#   'crossed',
#   'fingers',
#   'going',
#   "it's",
#   'just',
#   'keeping',
#   'my',
#   'to'],
#  ['83,',
#   'blanche',
#   'came',
#   'gore',
#   'hear',
#   'said',
#   'speak',
#   'this',
#   'time,"',
#   'to',
#   'vrooman,',
#   'who'],
#  ['"a',
#   'already',
#   'beach.',
#   'have',
#   'if',
#   'in',
#   'lot',
#   'of',
#   'palm',
#   'us',
#   'voted',
#   'west',
#   'who',
#   'wonder'],
#  ['are', 'count', 'going', 'not."', 'or', 'the', 'to', 'votes'],
#  [],
#  ['60,',
#   'again',
#   'an',
#   'but',
#   'early',
#   'favorite',
#   'gore,',
#   'now',
#   'run',
#   'this',
#   'to',
#   'was',
#   'year'],
#  ['become',
#   'calls.',
#   'defeat',
#   'has',
#   'he',
#   'his',
#   'one',
#   'rebuffed',
#   'since',
#   'spectacular',
#   'the'],
#  ['about',
#   'earning',
#   'global',
#   'leading',
#   'of',
#   'of',
#   'the',
#   'the',
#   'threat',
#   'voices',
#   'warming,'],
#  ['2007.', 'him', 'in', 'nobel', 'peace', 'prize', 'the'],
#  [],
#  ['"certainly',
#   'always',
#   'and',
#   'be',
#   "beach's",
#   'of',
#   'palm',
#   'part',
#   'this',
#   'will'],
#  ['a',
#   'as',
#   'as',
#   'berger,',
#   "florida's",
#   'his',
#   'history',
#   'history,"',
#   'mitchell',
#   'said',
#   'well'],
#  ['"he',
#   'and',
#   'democratic',
#   'florida',
#   'friend',
#   'fundraiser',
#   'gore.',
#   'in',
#   'of',
#   'prominent'],
#  ['a',
#   'all',
#   'and',
#   'and',
#   'defeat',
#   'from',
#   'get',
#   'has',
#   'how',
#   'move',
#   'on',
#   'shown',
#   'to',
#   'up',
#   'us'],
#  ['life."', 'rebuild', 'your'],
#  [],
#  ['a',
#   'al-nahyan,',
#   'bin',
#   'mansour',
#   'member',
#   'sheikh',
#   'the',
#   'when',
#   'zayed'],
#  ['abu',
#   'buy',
#   'dhabi,',
#   'family',
#   'in',
#   'last',
#   'month',
#   'of',
#   'of',
#   'royal',
#   'swooped',
#   'the',
#   'the',
#   'to'],
#  ['british',
#   'city,',
#   "club's",
#   'fans',
#   'manchester',
#   'soccer',
#   'team',
#   'the',
#   'were'],
#  ['bravado',
#   'by',
#   "emirate's",
#   'front',
#   'man.',
#   'of',
#   'oil-rich',
#   'the',
#   'the',
#   'titillated'],
#  ['a',
#   'al-fahim,',
#   'developer',
#   'managed',
#   'property',
#   'purchase',
#   'sulaiman',
#   'the',
#   'who'],
#  ['a',
#   'and',
#   'biggest',
#   'family,',
#   'for',
#   'lure',
#   "soccer's",
#   'stars',
#   'the',
#   'to',
#   'vowed',
#   'win'],
#  ['and',
#   'and',
#   'anderson',
#   'championship,',
#   'demi',
#   'european',
#   'pamela',
#   'socialized',
#   'with'],
#  ['moore.'],
#  [],
#  ['a',
#   'appoint',
#   'but',
#   'came',
#   'chairman',
#   'it',
#   'run',
#   "team's",
#   'the',
#   'time',
#   'to',
#   'to',
#   'when'],
#  ['business',
#   'by',
#   'fahim',
#   'flashy',
#   'of',
#   'one',
#   'replaced',
#   'royal',
#   'side,',
#   'the',
#   'the',
#   'was'],
#  ['advisers,',
#   'al-mubarak,',
#   "family's",
#   'khaldoon',
#   'most',
#   'the',
#   'trusted'],
#  ['32-year-old',
#   'abu',
#   'development',
#   "dhabi's",
#   'director',
#   'fund,',
#   'high-profile',
#   'of'],
#  ['mubadala.'],
#  [],
#  ['and',
#   'designer',
#   'his',
#   'mubarak',
#   'perfectly',
#   'stubble',
#   'suit,',
#   'tailored',
#   'with'],
#  ['a',
#   'aplomb',
#   'as',
#   'cut',
#   'figure',
#   'from',
#   'he',
#   'his',
#   'new',
#   'of',
#   'suave',
#   'team',
#   'the',
#   'watched'],
#  ['a',
#   'about',
#   'developing',
#   'he',
#   'issued',
#   'later,',
#   'soothing',
#   'stands.',
#   'statement',
#   'the'],
#  ['10-year',
#   'and',
#   'club,',
#   'for',
#   'he',
#   'plan',
#   'players',
#   'the',
#   'the',
#   'then',
#   'younger'],
#  ['abu',
#   'arab',
#   'dhabi,',
#   'discreetly',
#   'is',
#   'of',
#   'part',
#   'returned',
#   'the',
#   'to',
#   'united',
#   'which'],
#  ['emirates.'],
#  [],
#  ['and',
#   'bluster',
#   'for',
#   'from',
#   'message',
#   'need',
#   'no',
#   'sheiks:',
#   'starlets;',
#   'the',
#   'the'],
#  ['$330',
#   '--',
#   '200',
#   'abu',
#   'all',
#   "dhabi's",
#   'it',
#   'million',
#   'million,',
#   'money',
#   'of',
#   'or',
#   'pounds,'],
#  ['--', 'for', 'itself.', 'speaks'],
#  [],
#  ['again',
#   'also',
#   'as',
#   'friday,',
#   'is',
#   'it',
#   'mansour,',
#   'on',
#   'sheikh',
#   'spoke',
#   'who'],
#  ['chairman',
#   'co.,',
#   'international',
#   'invested',
#   'investment',
#   'of',
#   'petroleum',
#   'the'],
#  ['($5.77',
#   '3.5',
#   'almost',
#   'barclays,',
#   'billion',
#   'billion)',
#   'in',
#   'of',
#   'one',
#   'pounds'],
#  ['--',
#   '16',
#   'a',
#   'banks',
#   "britain's",
#   'could',
#   'for',
#   'largest',
#   'percent',
#   'reach',
#   'stake',
#   'that'],
#  ['bank.', 'of', 'the'],
#  [],
#  ['15.5',
#   'another',
#   'hold',
#   'investors',
#   'percent.',
#   'qatari',
#   'to',
#   'up',
#   'will'],
#  [],
#  ['and',
#   'big',
#   'funds',
#   'in',
#   'markets',
#   'some',
#   'sovereign',
#   'turmoil',
#   'wealth',
#   'with'],
#  ['bets,',
#   'billions',
#   'hanging',
#   'losing',
#   'of',
#   'on',
#   'one',
#   'over',
#   'questions',
#   'the',
#   'western'],
#  ['been',
#   'disorder',
#   'economic',
#   'has',
#   'new',
#   'sovereign',
#   'the',
#   'wealth',
#   'whether',
#   'world'],
#  ['and',
#   'around',
#   'continue',
#   'funds',
#   'other',
#   'slosh',
#   'state',
#   'the',
#   'the',
#   'to',
#   'will',
#   'world.'],
#  ['a', "barclay's", 'investment', 'new', 'offered', 'resounding', 'yes.'],
#  [],
#  ['"we',
#   'are',
#   'away',
#   'be',
#   'down,"',
#   'going',
#   'is',
#   'market',
#   'not',
#   'running',
#   'the',
#   'to',
#   'when'],
#  ['"there',
#   'a',
#   'a',
#   'are',
#   'brief',
#   'in',
#   'interview',
#   'last',
#   'lot',
#   'month.',
#   'mubarak',
#   'of',
#   'said'],
#  ['interesting', 'opportunities', 'out', 'there."'],
#  [],
#  ['also',
#   'are',
#   'calls',
#   'for',
#   'funds,',
#   'greater',
#   'of',
#   'regulation',
#   'state-run',
#   'there'],
#  ['$145.29',
#   'a',
#   'a',
#   'and',
#   'barrel',
#   'fall',
#   'fears',
#   'from',
#   'global',
#   'of',
#   "oil's",
#   'recession',
#   'to'],
#  ['$67.81',
#   '9',
#   'about',
#   'abu',
#   'atop',
#   'but',
#   'dhabi',
#   'friday.',
#   'just',
#   'of',
#   'on',
#   'percent',
#   'sits'],
#  ['and',
#   'cash',
#   'has',
#   'oil',
#   'reserves',
#   'spare.',
#   'still',
#   'the',
#   'the',
#   'to',
#   "world's"],
#  [],
#  ['been',
#   'dubai,',
#   'has',
#   'it',
#   'its',
#   'larger-than-life',
#   'neighbor',
#   'unlike',
#   'until'],
#  ['about',
#   'but',
#   'deploys',
#   'how',
#   'hyperdiscreet',
#   'it',
#   'its',
#   'now',
#   'recently',
#   'windfall.'],
#  ['--',
#   'attention',
#   'emerging',
#   'for',
#   'from',
#   'is',
#   'is',
#   'it',
#   'it',
#   'looking',
#   'shadows,',
#   'that',
#   'the'],
#  ['but',
#   'dubai',
#   'flash-and-dash',
#   'for.',
#   'is',
#   'kind',
#   'known',
#   'not',
#   'of',
#   'that',
#   'the'],
#  [],
#  ['a',
#   'and',
#   'ascent',
#   'avatar.',
#   'from',
#   'had',
#   'he',
#   'is',
#   'meteoric',
#   'mubarak',
#   'perfect',
#   'the'],
#  ['a',
#   'a',
#   'abu',
#   'company',
#   "dhabi's",
#   'executive',
#   'for',
#   'oil',
#   'on',
#   'powerful',
#   'sales',
#   'seat',
#   'to'],
#  ['abu',
#   'and',
#   'council',
#   "dhabi's",
#   'executive',
#   'governing',
#   'mubadala,',
#   'of',
#   'oversight'],
#  ['aggressive',
#   'development',
#   "emirate's",
#   'fund,',
#   'has',
#   'made',
#   'recently',
#   'the',
#   'which'],
#  ['highly', 'investments.', 'several', 'strategic', 'visible'],
#  [],
#  ['carlyle,',
#   'equity',
#   'fund',
#   'have',
#   'in',
#   'included',
#   'private',
#   'stakes',
#   'the',
#   'these'],
#  ['advanced',
#   'american',
#   'and',
#   'chip',
#   'computer',
#   'devices',
#   'maker',
#   'micro',
#   'more',
#   'the'],
#  ['electric.', 'general', 'recently'],
#  [],
#  ['abu',
#   'dhabi',
#   "emirate's",
#   'fund,',
#   'investment',
#   'sovereign',
#   'the',
#   'the'],
#  ['an',
#   'as',
#   'authority,',
#   'has',
#   'is',
#   'it',
#   'largest.',
#   'recognized',
#   'the',
#   "world's"],
#  ['$10',
#   '$600',
#   'billion,',
#   'compared',
#   'estimated',
#   'more',
#   "mubadala's",
#   'than',
#   'with'],
#  ['a',
#   'and',
#   'behind',
#   'billion,',
#   'of',
#   'operates',
#   'secrecy.',
#   'the',
#   'thick',
#   'veil'],
#  ['abroad',
#   'abu',
#   'as',
#   "authority's",
#   "dhabi's",
#   'invest',
#   'is',
#   'mandate',
#   'oil',
#   'surplus',
#   'to'],
#  ['a',
#   'charge',
#   'hands-off',
#   'in',
#   'invest',
#   'investor;',
#   'is',
#   "mubadala's",
#   'portfolio',
#   'to'],
#  ['a',
#   'a',
#   'and',
#   'both',
#   'commercial',
#   'joint',
#   'promise',
#   'strategic',
#   'that',
#   'ventures'],
#  ['emirate.', 'for', 'payback', 'the'],
#  [],
#  ['"mubarak',
#   'abu',
#   'become',
#   "dhabi's",
#   'has',
#   'interface',
#   'of',
#   'rest',
#   'the',
#   'the',
#   'with'],
#  ['a',
#   'at',
#   'christopher',
#   'davidson,',
#   'durham',
#   'professor',
#   'said',
#   'world,"'],
#  ['abu',
#   'an',
#   'britain,',
#   'economic',
#   'has',
#   'history',
#   'in',
#   'of',
#   'university',
#   'who',
#   'written'],
#  ['"he',
#   'and',
#   'can',
#   'crown',
#   'dhabi.',
#   'ear',
#   'has',
#   'he',
#   'in',
#   'of',
#   'prince',
#   'step',
#   'the',
#   'the'],
#  ['he', 'is', 'needed."', 'whenever'],
#  [],
#  ['appeared',
#   'chief',
#   'cnbc',
#   'executive,',
#   "ge's",
#   'mubarak',
#   'on',
#   'summer',
#   'this',
#   'with'],
#  ['$8',
#   'an',
#   'billion',
#   'focused',
#   'immelt,',
#   'jeffrey',
#   'joint',
#   'promote',
#   'r.',
#   'to',
#   'venture'],
#  ['africa,',
#   'and',
#   'and',
#   'commercial',
#   'east',
#   'finance',
#   'he',
#   'in',
#   'middle',
#   'on',
#   'openly',
#   'the'],
#  ['10',
#   'become',
#   "ge's",
#   'largest',
#   "mubadala's",
#   'of',
#   'one',
#   'plan',
#   'signaled',
#   'to'],
#  ['shareholders.'],
#  [],
#  ['by',
#   'completed',
#   'expected',
#   'have',
#   'is',
#   'its',
#   'july,',
#   'mubadala',
#   'planned',
#   'to'],
#  ['a',
#   'accumulation',
#   'commitment',
#   'could',
#   'financial',
#   'ge',
#   'of',
#   'stock,',
#   'surpass',
#   'that'],
#  ['$3', 'billion.'],
#  [],
#  ['a',
#   'extent,',
#   'increasingly',
#   'large',
#   "mubadala's",
#   'profile',
#   'public',
#   'to'],
#  ['$145.29',
#   'a',
#   'a',
#   'barrel',
#   'in',
#   'of',
#   'of',
#   'oil',
#   'peak',
#   'price',
#   'rise',
#   'the',
#   'the',
#   'to',
#   'tracked'],
#  ['a',
#   'create',
#   'falling',
#   'likely',
#   'most',
#   'oil',
#   'rising',
#   'summer.',
#   'surpluses',
#   'this',
#   'will'],
#  ['and',
#   'economies',
#   'federal',
#   'for',
#   'local',
#   'markets.',
#   'money',
#   'need',
#   'support',
#   'the',
#   'to'],
#  ['already',
#   'arab',
#   'disbursed',
#   'emirates',
#   'government',
#   'has',
#   'more',
#   'of',
#   'the',
#   'united'],
#  ['$30', 'banks.', 'billion', 'local', 'support', 'than', 'to'],
#  [],
#  ['al-mokarrab,',
#   'but',
#   'chief',
#   'for',
#   'officer',
#   'operating',
#   'the',
#   'waleed'],
#  ['average',
#   'last',
#   'mubadala,',
#   'of',
#   'oil',
#   'out',
#   'points',
#   'price',
#   'that',
#   'the',
#   'was',
#   'year'],
#  ['"we',
#   '$80.',
#   'a',
#   'change',
#   'do',
#   'expect',
#   'for',
#   'he',
#   'massive',
#   'next',
#   'not',
#   'said,',
#   'year,"'],
#  ['coming.', 'deals', 'keep', 'suggesting', 'the', 'will'],
#  [],
#  ['aerospace,',
#   'far,',
#   'has',
#   'health',
#   'in',
#   'invested',
#   'like',
#   'mubadala',
#   'sectors',
#   'so'],
#  ['aluminum',
#   'and',
#   'care,',
#   'computer',
#   'gas',
#   'production,',
#   'purification,',
#   'water'],
#  ['and,', 'chips', 'commercial', 'finance.', 'ge,', 'with'],
#  [],
#  ['"we',
#   'a',
#   'are',
#   'company,"',
#   'development',
#   'like',
#   'literally',
#   'mokarrab.',
#   'said'],
#  ['a',
#   'and',
#   'educated',
#   'fondness',
#   'has',
#   'he',
#   'in',
#   'mubarak,',
#   'states',
#   'the',
#   'united',
#   'was'],
#  ['american-style', 'business', 'for', 'jargon.', 'school'],
#  [],
#  ['abu',
#   'call',
#   'dhabi',
#   'government',
#   'shareholder,',
#   'the',
#   'their',
#   'they',
#   'to',
#   'wit,'],
#  ['"game',
#   'and',
#   'as',
#   'changers"',
#   'fluently',
#   'investments',
#   'of',
#   'refer',
#   'speak',
#   'to'],
#  ['internal', 'of', 'rates', 'return.'],
#  [],
#  ['"we',
#   'and',
#   'businesses',
#   'create',
#   'from',
#   'money',
#   'on',
#   'our',
#   'shareholder',
#   'take',
#   'we'],
#  ['"we',
#   'a',
#   'added.',
#   'are',
#   'building',
#   'country',
#   'ground,"',
#   'mokarrab',
#   'the'],
#  ['together."'],
#  [],
#  ['authority,',
#   'debt',
#   'help',
#   'investment',
#   'mubadala',
#   'the',
#   'to',
#   'unlike',
#   'uses'],
#  ['--',
#   'abu',
#   'crucially,',
#   'finance',
#   'guarantee',
#   'of',
#   'projects',
#   'some',
#   'the',
#   'with'],
#  ['60',
#   'a',
#   'cash',
#   "dhabi's",
#   'financed',
#   'is',
#   'of',
#   'on',
#   'portfolio',
#   'ratio',
#   'reserves.',
#   'the'],
#  ['40', 'debt.', 'equity', 'percent', 'percent', 'to'],
#  [],
#  ['acumen',
#   'and',
#   'have',
#   'his',
#   "mubarak's",
#   'smooth',
#   'ways',
#   'western',
#   'while'],
#  ['close',
#   'crown',
#   'his',
#   'impressed',
#   'investors,',
#   'prince,',
#   'relationship',
#   'the',
#   'with'],
#  ['abu',
#   'and',
#   "dhabi's",
#   'expected',
#   'half-brother',
#   'his',
#   'of',
#   'ruler',
#   'the',
#   'younger'],
#  ['an',
#   'behind',
#   'he',
#   'heads',
#   'increasing',
#   'is',
#   "mubarak's",
#   'prominence.',
#   'successor,'],
#  ['advisory',
#   'affairs',
#   'authority',
#   'called',
#   'elite',
#   'executive',
#   'group',
#   'that',
#   'the'],
#  ['advises',
#   'considered',
#   'crown',
#   'for',
#   'is',
#   'leading',
#   'prince,',
#   'the',
#   'the',
#   'voice',
#   'who'],
#  ['a',
#   'cautiously',
#   'economic,',
#   'emirate,',
#   'modernizing',
#   'of',
#   'on',
#   'range',
#   'the'],
#  ['and',
#   'communications',
#   'compared',
#   'financial,',
#   'issues.',
#   'its',
#   'social',
#   'to',
#   'with'],
#  ['abu',
#   'and',
#   'arabia',
#   'dhabi',
#   'flanking',
#   'has',
#   'iran,',
#   'made',
#   'neighbors,',
#   'saudi',
#   'two'],
#  ['and',
#   'bold',
#   'disposition',
#   'its',
#   'its',
#   'outlook',
#   'remains',
#   'secretive',
#   'strides,',
#   'yet'],
#  ['a',
#   'cautious,',
#   'conservative',
#   'its',
#   'of',
#   'of',
#   'reflection',
#   'ruler,',
#   'spirit',
#   'the'],
#  ['al-nahyan.', 'bin', 'khalifa', 'sheik', 'zayed'],
#  [],
#  ['"if',
#   'all',
#   'all',
#   'crucial.',
#   'have',
#   'makes',
#   'more',
#   'mubarak',
#   'of',
#   'the',
#   'which',
#   'you'],
#  ['and',
#   'and',
#   'can',
#   'crown',
#   'for',
#   'his',
#   'leadership',
#   'prince',
#   'skills',
#   'speak',
#   'the',
#   'you'],
#  ['a',
#   'combination,"',
#   'david',
#   'effective',
#   'have',
#   'is',
#   'money,',
#   'said',
#   'that',
#   'very',
#   'you'],
#  ['a', 'carlyle', 'co-founder', 'group.', 'of', 'rubenstein,', 'the'],
#  [],
#  ['and',
#   'continuing',
#   'fall',
#   "gulf's",
#   'oil',
#   'persian',
#   'prices',
#   'still,',
#   'the',
#   'to',
#   'with'],
#  ['analysts',
#   'busy',
#   'economies',
#   'expect',
#   'many',
#   'own',
#   'showing',
#   'strains,',
#   'the'],
#  ['--', 'deal-making', 'last', 'of', 'slow', 'somewhat.', 'the', 'to', 'year'],
#  [],
#  ['$60',
#   'a',
#   'a',
#   'abu',
#   'around',
#   'barrel,',
#   'clears',
#   'dhabi',
#   'even',
#   'healthy',
#   'oil',
#   'with'],
#  ['and',
#   'but',
#   'cautiously',
#   'emirate',
#   'is',
#   'likely',
#   'move',
#   'surplus',
#   'the',
#   'to'],
#  ['a',
#   'active',
#   'in',
#   'international',
#   'more',
#   'purposefully',
#   'role',
#   'the',
#   'toward'],
#  ['and',
#   'and',
#   'center.',
#   'community,',
#   'financial',
#   'front',
#   'mubadala',
#   'mubarak',
#   'with'],
#  [],
#  ['"he',
#   'a',
#   'age,"',
#   'bandwidth',
#   'for',
#   "ge's",
#   'has',
#   'his',
#   'immelt,',
#   'lot',
#   'of',
#   'said'],
#  ['"he',
#   'a',
#   'a',
#   'calls',
#   'chief,',
#   'face',
#   'for',
#   'friend.',
#   'great',
#   'is',
#   'mubarak',
#   'public',
#   'who'],
#  ['abu',
#   'as',
#   'as',
#   'being',
#   'business',
#   'dhabi',
#   'great',
#   'leaders',
#   'of',
#   'one',
#   'the',
#   'well',
#   'young'],
#  ['in', 'the', 'world."'],
#  [],
#  ['a',
#   'blow',
#   'chemicals',
#   'hexion',
#   'legal',
#   'on',
#   'serious',
#   'specialty',
#   'suffered'],
#  ['a',
#   'court',
#   'extend',
#   'friday',
#   'judge',
#   'new',
#   'refused',
#   'state',
#   'the',
#   'to',
#   'when',
#   'york'],
#  ['banks',
#   'commitments',
#   "company's",
#   'for',
#   'from',
#   'its',
#   'lending',
#   'proposed',
#   'the'],
#  ['huntsman.', 'merger', 'with'],
#  [],
#  ['$6.5',
#   'billion',
#   'deal',
#   'decision',
#   'fate',
#   'into',
#   'of',
#   'the',
#   'the',
#   'the',
#   'throws'],
#  ['and',
#   'and',
#   'could',
#   'doubt,',
#   'equity',
#   'hexion',
#   'its',
#   'leave',
#   'parent,',
#   'private',
#   'the'],
#  ['apollo',
#   'billions',
#   'dollars',
#   'firm',
#   'for',
#   'hook',
#   'in',
#   'management,',
#   'of',
#   'on',
#   'the'],
#  ['damages.', 'legal'],
#  [],
#  ['and',
#   'banks,',
#   'commitments',
#   'credit',
#   'financing',
#   'of',
#   'suisse',
#   'the',
#   'the'],
#  ['are', 'bank,', 'deutsche', 'expire', 'on', 'saturday.', 'scheduled', 'to'],
#  [],
#  ['bransten',
#   'c.',
#   'court',
#   'eileen',
#   'friday,',
#   'her',
#   'in',
#   'justice',
#   'of',
#   'on',
#   'ruling',
#   'the'],
#  ['banks',
#   'court',
#   'entitled',
#   'ruled',
#   'state',
#   'supreme',
#   'that',
#   'the',
#   'their',
#   'to',
#   'were'],
#  ['contract.', 'original'],
#  ...]

# %%
# b)
def sorting_lines2():
    lines = text.strip(string.punctuation).lower().split('\n')
    for line in lines:
        a = [seq for seq in line.split()]
        yield(sorted(a))
        
print(ord("f"))
list(sorting_lines2())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 8
#       5         a = [seq for seq in line.split()]
#       6         yield(sorted(a))
# ----> 8 print(ord("foul"))
#       9 list(sorting_lines2())
#
# TypeError: ord() expected a character, but string of length 4 found

# %%
# c)

# %%
# d)

# %% [markdown]
# #### 3. Computing basic statistics
#
# a. Find the 50 most common words
# b. Find the words in the NYT that end in "zz"
# c. Count the lines, the words, and the characters
# d. How many all uppercase words are there in this NYT file?
# e, How many 4-letter words?
# f. How many different words are there with no vowels?
# g. **tricky:** How many “1 syllable” words are there?

# %%
# a)

# %%
# b)

# %%
# c)

# %%
# d)

# %%
# e)

# %%
# f)

# %%
# g)

# %% [markdown]
# #### 4. Compute ngrams
#
# a. Find the 10 most common bigrams
# b. Find the 10 most common trigrams

# %%
# a)

# %%
# b)

# %% [markdown]
# #### 5. Make a Concordance
#
# a. Create a concordance display for an arbitrary word. See the example below
#
# ![](../../Data/figs/Sample-concordance-lines-of-actually.png)

# %%
# a)

# %% [markdown]
# ***

# %% [markdown]
# ##### Extra Credit – Secret Message
# + The answers to the extra credit exercises will reveal a secret message.
# + We will be working with the following text file for these exercises:
# [Link to Text](https://web.stanford.edu/class/cs124/lec/secret_ec.txt)
# (No starter code in the Extra Credit)

# %% [markdown]
# ##### Extra Credit Exercise 1
# • Find the 2 most common words in secret_ec.txt containing the letter e.
# • Your answer will correspond to the first two words of the secret message.

# %% [markdown]
# ##### Extra Credit Exercise 2
# • Find the 2 most common bigrams in secret_ec.txt where the second word in the bigram ends with a consonant.
# • Your answer will correspond to the next four words of the secret message.

# %% [markdown]
# ##### Extra Credit Exercise 3
# • Find all 5-letter-long words that only appear once in secret_ec.txt.
# • Concatenate your result. This will be the final word of the secret message.
#
# What is the secret message?
