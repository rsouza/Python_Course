# %% [markdown]
# FGV - Escola de Matemática Aplicada
# ==
# Introdução à Programação com a Linguagem Python
# --

# %% [markdown]
# #### Resolvendo o [problema 3](https://projecteuler.net/problem=3) do Project Euler:
#
#
# The prime factors of 13195 are 5, 7, 13 and 29.
# What is the largest prime factor of the number 600851475143 ?

# %%
def maior_fator_primo(n):
    #gerando primos até n/2
    seq = range(3,int(n/2.)+1)
    primos = [2]
    for candidato in seq:
        E_primo = True
        for primo in primos:
            if candidato%primo == 0:
                E_primo = False
        if E_primo:
            primos.append(candidato)
    fatores = []
    for primo in primos:
        if n%primo == 0:
            fatores.append(primo)
    print(fatores)
    return fatores

# %%
maior_fator_primo(13195)
# Out:
# [5, 7, 13, 29]
# [5, 7, 13, 29]

# %%
def maior_fator_primo2(n):
    primos = [2]
    candidato_a_primo = 3
    fatores = []
    while candidato_a_primo < (int(n/2.)+1):
        E_primo = True
        for primo in primos:
            if candidato_a_primo%primo == 0:
                E_primo = False
        if E_primo:
            primos.append(candidato_a_primo)
            if n%candidato_a_primo == 0:
                fatores.append(candidato_a_primo)
        candidato_a_primo +=1
    print(fatores)
    return fatores

# %%
maior_fator_primo2(600851475143)

# %%
def is_prime(n):
    if n <= 3:
        return n >= 2
    if n % 2 == 0 or n % 3 == 0:
        return False
    for i in range(5, int(n ** 0.5) + 1, 6):
        if n % i == 0 or n % (i + 2) == 0:
            return False
    return True

# %%
def maior_fator_primo3(n):
    fatores = []
    candidato_a_fator = 2
    while candidato_a_fator < (int(n/2.)+1):
            if is_prime(candidato_a_fator) and n%candidato_a_fator == 0:
                fatores.append(candidato_a_fator)
            candidato_a_fator +=1
    print(fatores)
    return fatores

# %%
maior_fator_primo3(600851475143)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-1f1aa28371f6> in <module>()
# ----> 1 maior_fator_primo3(600851475143)
#
# <ipython-input-61-10bc923465ae> in maior_fator_primo3(n)
#       3     candidato_a_fator = 2
#       4     while candidato_a_fator < (int(n/2.)+1):
# ----> 5             if is_prime(candidato_a_fator) and n%candidato_a_fator == 0:
#       6                 fatores.append(candidato_a_fator)
#       7             candidato_a_fator +=1
#
# <ipython-input-60-83a369c5e04d> in is_prime(n)
#       5         return False
#       6     for i in range(5, int(n ** 0.5) + 1, 6):
# ----> 7         if n % i == 0 or n % (i + 2) == 0:
#       8             return False
#       9     return True
#
# KeyboardInterrupt:
